# %% [markdown]
# # Collaborative Filtering
# With your best friends; Cookie Optimizers :D

# %% [markdown]
# ## CiteULike

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm==2.0.0 in c:\users\micha\appdata\local\conda\conda\envs\deeplearning-02456\lib\site-packages (2.0.0)
#
#     Linking successful
#     C:\Users\Micha\AppData\Local\conda\conda\envs\deeplearning-02456\lib\site-packages\en_core_web_sm
#     -->
#     C:\Users\Micha\AppData\Local\conda\conda\envs\deeplearning-02456\lib\site-packages\spacy\data\en
#
#     You can now load the model via spacy.load('en')

# %%
from torchtext.data import Dataset, BucketIterator, Field, TabularDataset, Iterator
from torchtext.vocab import Vocab
import pandas as pd
import numpy as np
import spacy

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch import nn
import torch.nn.utils.rnn as rnn_utils

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def condence(nparr):
    uniq = np.unique(nparr)
    name2idx = {o:i for i,o in enumerate(uniq)}
    return np.array([name2idx[o] for o in nparr]), uniq

## Read set
text_information_index = 1
max_len = 1000
data='../datasets/citeulike/raw-data.csv'
#interactions = '../datasets/citeulike/user-info-small.csv'
interactions = '../datasets/citeulike/user-info.csv'
rawtext = pd.read_csv(data)
interactions = pd.read_csv(interactions)
interactions["user.id"], uniq = condence(interactions["user.id"].values)
sizes = [0.7, 0.2]

interactions = interactions.sample(frac=1) # Shuffle
filt = interactions["doc.id"].map(lambda x: len(rawtext.iloc[x,text_information_index])) <= max_len
interactions = interactions[filt]
interactions["doc.id"] = interactions["doc.id"].transform(lambda idx: rawtext.iloc[int(idx),text_information_index])

n = len(interactions)
train_size = int(sizes[0] * n)
val_size = int(sizes[1] * n)
test_size = n - train_size - val_size

train = interactions[:train_size]
val = interactions[train_size:train_size+val_size]
test = interactions[train_size+val_size:]

n = len(train)

uniq_items = np.unique(rawtext["doc.id"])[:-1]
uniq_users = np.unique(train["user.id"])[:-1]
items = set((x[0],x[1]) for x in train[["user.id","doc.id"]].values)

pairs = []
i = 0
while(i < n):
    
    item = np.random.choice(uniq_items, size = 1)[0]
    text = rawtext.iloc[int(item),text_information_index]
    user = np.random.choice(uniq_users, size = 1)[0]
    if len(text.split(' ')) <= max_len and (user,item) not in items:
        i += 1
        pairs += [(user,text,0)]
        items.add((user,item))

interactionsNegatives = np.vstack((train, pairs))

train = pd.DataFrame(data = interactionsNegatives, columns = ["user.id","doc.id", "rating"])

val.to_csv('../datasets/citeulike/val.csv', header = False, index = False)
test.to_csv('../datasets/citeulike/test.csv', header = False, index = False)

del interactionsNegatives, items, uniq_items, uniq_users, pairs, interactions, val, test

train = train.sample(frac=1) #shuffle panda style

train.to_csv('../datasets/citeulike/train.csv', header = False, index = False)

max_length = max(train["doc.id"].map(lambda x: len(x.split(' '))))
print(max_length)

del train
# Out:
# 33

# %%
spacy_en = spacy.load('en')

def tokenizer(text): # create a tokenizer function
    return [tok.text for tok in spacy_en.tokenizer(text)]

TEXT = Field(sequential=True, lower=True, include_lengths=True, fix_length=max_length)
LABEL = Field(sequential=False, use_vocab=False)
ID = Field(sequential=False, use_vocab=False)

train, val, test = TabularDataset.splits(
        path='../datasets/citeulike', train='train.csv',
        validation='val.csv', test='test.csv', format='csv',
        fields=[('ID', ID), ('Text', TEXT), ('Label', LABEL)])

TEXT.build_vocab(train, vectors="glove.6B.100d")
LABEL.build_vocab(train)
ID.build_vocab(train)

# %%
print('Text fields:')
#print('keys of TEXT.vocab:', list(TEXT.vocab.__dict__.keys()))
print(' size of vocabulary:', len(TEXT.vocab))
print(" vocabulary's embedding dimension:", TEXT.vocab.vectors.size())
print(' no. times the "the" appear in the dataset:', TEXT.vocab.freqs['the'])
# Out:
# Text fields:
#  size of vocabulary: 14498
#  vocabulary's embedding dimension: torch.Size([14498, 100])
#  no. times the "the" appear in the dataset: 93261

# %%
batch_size = (101, 102, 103)

train_iter, val_iter, test_iter = BucketIterator.splits(
    (train, val, test), batch_sizes=batch_size, sort_key=lambda x: len(x.Text), sort_within_batch = True, repeat = False)

# %%
# size of embeddings
TEXT_Shape = TEXT.vocab.vectors.size()
embedding_dim = TEXT_Shape[1]
num_items = TEXT_Shape[0]
num_users = len(ID.vocab.itos)
n_hidden = 104
l1_hidden = 105

# %%
class CFNN(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim=embedding_dim, n_hidden=n_hidden, l1_hidden=l1_hidden):
        super(CFNN, self).__init__()
        self.user_emb = nn.Embedding(num_users, embedding_dim)
        self.item_emb = nn.Embedding(num_items, embedding_dim)
        self.lin1 = nn.Linear(n_hidden+embedding_dim, l1_hidden)
        self.lin2 = nn.Linear(l1_hidden, 1)
        self.drop0 = nn.Dropout(0.3)
        self.drop1 = nn.Dropout(0.3)
                
        # RNN decoding
        self.rnn = nn.LSTM(embedding_dim, n_hidden, bidirectional = True)
        self.rnnlin = nn.Linear(n_hidden*3, n_hidden)
        
        self.sigmoid = nn.Sigmoid()
        
        ## Attention module
        self.attn = nn.Linear(n_hidden*2, n_hidden)
        
    def forward(self, u, v, hidden, seq_lengths):
        #print(v.shape)
        U = self.user_emb(u)
        V = self.item_emb(v)
                
        ## Packing, Encoding, Padding
        packed = rnn_utils.pack_padded_sequence(V, seq_lengths).to(device)
        rnnOut, (hn, cn) = self.rnn(packed, hidden)
        padded, seq_lengths = rnn_utils.pad_packed_sequence(rnnOut, padding_value=0, total_length=max_length)
        seq_lengths = seq_lengths.to(device).float()
        
        # Divide each batch_element by sequence_element and sum. (mean by seq_length)
        padded = (padded.transpose(1,2) / seq_lengths).transpose(1,2)
        mean = padded.sum(dim=0)
        
        V_rnn = torch.cat([mean, hn[-1]], dim=1)
        V_rnn = F.relu(self.rnnlin(V_rnn))
                 
        x = torch.cat([U, V_rnn], dim=1)

        ## Classification
        x = self.drop0(x)
        x = F.relu(self.lin1(x))
        x = self.drop1(x)
        
        x = self.lin2(x)
        x = self.sigmoid(x)
        return x
    
    def init_hidden(self, batch_size):
        init = torch.zeros(2, batch_size, n_hidden).to(device)
        return (init,init)

# %%
## Training loop
def train(model, train_loader, optimizer, criterion, epoch, print_batch_p):
    model.train()
    
    acc_list = []
    loss_list = []
    
    for batch_idx, data in enumerate(train_loader):
        users = data.ID
        (items, seq_lengths) = data.Text
        ratings = data.Label
        batch_size = len(seq_lengths)
        
        users = users.long().to(device)
        items = items.long().to(device)
        ratings = ratings.float().to(device)      
        
        hidden_size = model.init_hidden(batch_size)
        optimizer.zero_grad()
        output = model(users, items, hidden_size, seq_lengths)
        loss = criterion(output, ratings)
        loss.backward()
        optimizer.step()
        
        # Print jumping
        percent = print_batch_p
        proc = int((len(train_loader.dataset)/batch_size)*percent)
        proc = proc if proc >= 1 else 1
        
        # Calculate accuracy
        TP,FP,TN,FN = 0,0,0,0
        output_flat = [0 if o < 0.5 else 1 for o in output.data]
        for y,yhat in zip(ratings.data, output_flat):
            y = int(y)
            if yhat == 0:
                if y != yhat:
                    FN += 1
                else:
                    TN += 1
            else:
                if y != yhat:
                    FP += 1
                else:
                    TP += 1
            
        acc_list += [(TP + TN)/(TP+FP+TN+FN)]
        loss_list += [loss.item()]
        
        if (batch_idx % proc == 0 and batch_idx != 0):
            loss_mean = sum(loss_list)/len(loss_list)
            acc_mean = sum(acc_list)/len(acc_list)
            percent = 100 * (batch_idx / (len(train_loader)-1))
            print(f'Train epoch {epoch:3d} ({percent:3.0f}%), Mean Accuracy: {acc_mean:2.5f}, Mean Loss: {loss_mean:2.5f}')
            
def validate(model, val_loader, criterion, epoch):
    model.eval()
    
    val_loss = 0
    TP,FP,TN,FN = 0,0,0,0
    
    with torch.no_grad():
        for batch_idx, data in enumerate(val_loader):
            users = data.ID
            (items, seq_lengths) = data.Text
            ratings = data.Label
            batch_size = len(seq_lengths)
            
            users = users.long().to(device)
            items = items.long().to(device)
            ratings = ratings.float().to(device)
            
            hidden_size = model.init_hidden(batch_size)
            output = model(users, items, hidden_size, seq_lengths)
            loss = criterion(output.float(), ratings)
            
            output_flat = [0 if o < 0.5 else 1 for o in output.data]
            for y,yhat in zip(ratings.data, output_flat):
                y = int(y)
                if yhat == 0:
                    if y != yhat:
                        FN += 1
                    else:
                        TN += 1
                else:
                    if y != yhat:
                        FP += 1
                    else:
                        TP += 1
            val_loss += loss.item() # sum up batch loss

    acc = (TP + TN)/(TP + TN + FP + FN)
    val_loss /= len(val_loader)
    print(f'Validation epoch {epoch:>3d} (100%), Accucary: {acc:>2.5f}, Mean Loss: {val_loss:>2.5f} \n')
    return acc, val_loss

def trainLoop(epochs, lr=0.001, wd = 1e-6, print_batch_p = 1, early_patience=5):
    # Define model    
    model = CFNN(num_users, num_items).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay = wd)
    
    accs = []
    losses = []
    best_acc = (-1,-1e16,1e16)
    best_loss = (-1,-1e16,1e16)
    early = 0
    
    for epoch in range(1, epochs + 1):
        train(model, train_iter, optimizer, criterion, epoch, print_batch_p)
        val_acc, val_loss = validate(model, val_iter, criterion, epoch)
        accs += [val_acc]
        losses += [val_loss]
        
        early += 1
        if val_acc > best_acc[-2]:
            early = 0
            best_acc = (epoch, val_acc, val_loss)
        if val_loss < best_loss[-1]:
            early = 0
            best_loss = (epoch, val_acc, val_loss)
        if early >= early_patience:
            break
        
    plt.plot(range(1,epoch+1),accs)
    plt.show()
    print(f'best validatation accu epoch: {best_acc[0]:>3.0f}, acc: {best_acc[1]:>2.5f}, mean loss: {best_acc[2]:>2.5f} \n')
    plt.plot(range(1,epoch+1),losses)
    plt.show()
    print(f'best validatation loss epoch: {best_loss[0]:>3.0f}, acc: {best_loss[1]:>2.5f}, mean loss: {best_loss[2]:>2.5f}')

# %%
trainLoop(epochs=100, lr=0.001, wd=1e-6, print_batch_p=0.33, early_patience=10)
# Out:
# Train epoch   1 ( 33%), Mean Accuracy: 0.55202, Mean Loss: 0.68205
# Train epoch   1 ( 66%), Mean Accuracy: 0.58565, Mean Loss: 0.66531
# Train epoch   1 ( 99%), Mean Accuracy: 0.60635, Mean Loss: 0.65330
# Validation epoch   1 (100%), Accucary: 0.51904, Mean Loss: 0.65790
#
# Train epoch   2 ( 33%), Mean Accuracy: 0.67309, Mean Loss: 0.60697
# Train epoch   2 ( 66%), Mean Accuracy: 0.67678, Mean Loss: 0.60373
# Train epoch   2 ( 99%), Mean Accuracy: 0.67894, Mean Loss: 0.60213
# Validation epoch   2 (100%), Accucary: 0.57916, Mean Loss: 0.63740
#
# Train epoch   3 ( 33%), Mean Accuracy: 0.69809, Mean Loss: 0.58175
# Train epoch   3 ( 66%), Mean Accuracy: 0.69848, Mean Loss: 0.58129
# Train epoch   3 ( 99%), Mean Accuracy: 0.69900, Mean Loss: 0.58101
# Validation epoch   3 (100%), Accucary: 0.61031, Mean Loss: 0.62781
#
# Train epoch   4 ( 33%), Mean Accuracy: 0.71359, Mean Loss: 0.56455
# Train epoch   4 ( 66%), Mean Accuracy: 0.70985, Mean Loss: 0.56764
# Train epoch   4 ( 99%), Mean Accuracy: 0.70936, Mean Loss: 0.56780
# Validation epoch   4 (100%), Accucary: 0.61746, Mean Loss: 0.62616
#
# Train epoch   5 ( 33%), Mean Accuracy: 0.72169, Mean Loss: 0.54714
# Train epoch   5 ( 66%), Mean Accuracy: 0.71894, Mean Loss: 0.55102
# Train epoch   5 ( 99%), Mean Accuracy: 0.71709, Mean Loss: 0.55411
# Validation epoch   5 (100%), Accucary: 0.64097, Mean Loss: 0.59398
#
# Train epoch   6 ( 33%), Mean Accuracy: 0.72923, Mean Loss: 0.53202
# Train epoch   6 ( 66%), Mean Accuracy: 0.72603, Mean Loss: 0.53641
# Train epoch   6 ( 99%), Mean Accuracy: 0.72502, Mean Loss: 0.53910
# Validation epoch   6 (100%), Accucary: 0.63822, Mean Loss: 0.60286
#
# Train epoch   7 ( 33%), Mean Accuracy: 0.73852, Mean Loss: 0.51514
# Train epoch   7 ( 66%), Mean Accuracy: 0.73533, Mean Loss: 0.52081
# Train epoch   7 ( 99%), Mean Accuracy: 0.73458, Mean Loss: 0.52326
# Validation epoch   7 (100%), Accucary: 0.64983, Mean Loss: 0.61013
#
# Train epoch   8 ( 33%), Mean Accuracy: 0.74902, Mean Loss: 0.49764
# Train epoch   8 ( 66%), Mean Accuracy: 0.74681, Mean Loss: 0.50189
# Train epoch   8 ( 99%), Mean Accuracy: 0.74658, Mean Loss: 0.50345
# Validation epoch   8 (100%), Accucary: 0.65529, Mean Loss: 0.59893
#
# Train epoch   9 ( 33%), Mean Accuracy: 0.76321, Mean Loss: 0.47526
# Train epoch   9 ( 66%), Mean Accuracy: 0.76151, Mean Loss: 0.47932
# Train epoch   9 ( 99%), Mean Accuracy: 0.75999, Mean Loss: 0.48217
# Validation epoch   9 (100%), Accucary: 0.66837, Mean Loss: 0.57152
#
# Train epoch  10 ( 33%), Mean Accuracy: 0.77854, Mean Loss: 0.45072
# Train epoch  10 ( 66%), Mean Accuracy: 0.77594, Mean Loss: 0.45528
# Train epoch  10 ( 99%), Mean Accuracy: 0.77340, Mean Loss: 0.45866
# Validation epoch  10 (100%), Accucary: 0.73296, Mean Loss: 0.49154
#
# Train epoch  11 ( 33%), Mean Accuracy: 0.78945, Mean Loss: 0.43044
# Train epoch  11 ( 66%), Mean Accuracy: 0.78736, Mean Loss: 0.43443
# Train epoch  11 ( 99%), Mean Accuracy: 0.78526, Mean Loss: 0.43895
# Validation epoch  11 (100%), Accucary: 0.74408, Mean Loss: 0.49473
#
# Train epoch  12 ( 33%), Mean Accuracy: 0.80138, Mean Loss: 0.40909
# Train epoch  12 ( 66%), Mean Accuracy: 0.79840, Mean Loss: 0.41561
# Train epoch  12 ( 99%), Mean Accuracy: 0.79487, Mean Loss: 0.42077
# Validation epoch  12 (100%), Accucary: 0.75669, Mean Loss: 0.49464
#
# Train epoch  13 ( 33%), Mean Accuracy: 0.81048, Mean Loss: 0.39450
# Train epoch  13 ( 66%), Mean Accuracy: 0.80513, Mean Loss: 0.40246
# Train epoch  13 ( 99%), Mean Accuracy: 0.80395, Mean Loss: 0.40560
# Validation epoch  13 (100%), Accucary: 0.79606, Mean Loss: 0.45210
#
# Train epoch  14 ( 33%), Mean Accuracy: 0.81798, Mean Loss: 0.38119
# Train epoch  14 ( 66%), Mean Accuracy: 0.81462, Mean Loss: 0.38893
# Train epoch  14 ( 99%), Mean Accuracy: 0.81260, Mean Loss: 0.39336
# Validation epoch  14 (100%), Accucary: 0.80201, Mean Loss: 0.46485
#
# Train epoch  15 ( 33%), Mean Accuracy: 0.82587, Mean Loss: 0.37090
# Train epoch  15 ( 66%), Mean Accuracy: 0.82163, Mean Loss: 0.37812
# Train epoch  15 ( 99%), Mean Accuracy: 0.81920, Mean Loss: 0.38244
# Validation epoch  15 (100%), Accucary: 0.80577, Mean Loss: 0.46214
#
# Train epoch  16 ( 33%), Mean Accuracy: 0.83472, Mean Loss: 0.35703
# Train epoch  16 ( 66%), Mean Accuracy: 0.82914, Mean Loss: 0.36754
# Train epoch  16 ( 99%), Mean Accuracy: 0.82648, Mean Loss: 0.37231
# Validation epoch  16 (100%), Accucary: 0.80208, Mean Loss: 0.48250
#
# Train epoch  17 ( 33%), Mean Accuracy: 0.83978, Mean Loss: 0.34760
# Train epoch  17 ( 66%), Mean Accuracy: 0.83623, Mean Loss: 0.35545
# Train epoch  17 ( 99%), Mean Accuracy: 0.83196, Mean Loss: 0.36221
# Validation epoch  17 (100%), Accucary: 0.83426, Mean Loss: 0.43049
#
# Train epoch  18 ( 33%), Mean Accuracy: 0.84736, Mean Loss: 0.33566
# Train epoch  18 ( 66%), Mean Accuracy: 0.84184, Mean Loss: 0.34521
# Train epoch  18 ( 99%), Mean Accuracy: 0.83798, Mean Loss: 0.35203
# Validation epoch  18 (100%), Accucary: 0.82108, Mean Loss: 0.45715
#
# Train epoch  19 ( 33%), Mean Accuracy: 0.85244, Mean Loss: 0.32640
# Train epoch  19 ( 66%), Mean Accuracy: 0.84654, Mean Loss: 0.33678
# Train epoch  19 ( 99%), Mean Accuracy: 0.84334, Mean Loss: 0.34288
# Validation epoch  19 (100%), Accucary: 0.82718, Mean Loss: 0.44909
#
# Train epoch  20 ( 33%), Mean Accuracy: 0.85809, Mean Loss: 0.31875
# Train epoch  20 ( 66%), Mean Accuracy: 0.85278, Mean Loss: 0.32779
# Train epoch  20 ( 99%), Mean Accuracy: 0.84957, Mean Loss: 0.33316
# Validation epoch  20 (100%), Accucary: 0.82755, Mean Loss: 0.46601
#
# Train epoch  21 ( 33%), Mean Accuracy: 0.86016, Mean Loss: 0.31259
# Train epoch  21 ( 66%), Mean Accuracy: 0.85575, Mean Loss: 0.32025
# Train epoch  21 ( 99%), Mean Accuracy: 0.85246, Mean Loss: 0.32654
# Validation epoch  21 (100%), Accucary: 0.83113, Mean Loss: 0.45636
#
# Train epoch  22 ( 33%), Mean Accuracy: 0.86600, Mean Loss: 0.30237
# Train epoch  22 ( 66%), Mean Accuracy: 0.86117, Mean Loss: 0.31096
# Train epoch  22 ( 99%), Mean Accuracy: 0.85718, Mean Loss: 0.31829
# Validation epoch  22 (100%), Accucary: 0.83370, Mean Loss: 0.45618
#
# Train epoch  23 ( 33%), Mean Accuracy: 0.87009, Mean Loss: 0.29305
# Train epoch  23 ( 66%), Mean Accuracy: 0.86523, Mean Loss: 0.30316
# Train epoch  23 ( 99%), Mean Accuracy: 0.86094, Mean Loss: 0.31087
# Validation epoch  23 (100%), Accucary: 0.83809, Mean Loss: 0.45078
#
# Train epoch  24 ( 33%), Mean Accuracy: 0.87311, Mean Loss: 0.28725
# Train epoch  24 ( 66%), Mean Accuracy: 0.86804, Mean Loss: 0.29779
# Train epoch  24 ( 99%), Mean Accuracy: 0.86420, Mean Loss: 0.30500
# Validation epoch  24 (100%), Accucary: 0.83789, Mean Loss: 0.44841
#
# Train epoch  25 ( 33%), Mean Accuracy: 0.87762, Mean Loss: 0.28050
# Train epoch  25 ( 66%), Mean Accuracy: 0.87258, Mean Loss: 0.28926
# Train epoch  25 ( 99%), Mean Accuracy: 0.86730, Mean Loss: 0.29858
# Validation epoch  25 (100%), Accucary: 0.84445, Mean Loss: 0.45335
#
# Train epoch  26 ( 33%), Mean Accuracy: 0.87983, Mean Loss: 0.27530
# Train epoch  26 ( 66%), Mean Accuracy: 0.87424, Mean Loss: 0.28588
# Train epoch  26 ( 99%), Mean Accuracy: 0.87078, Mean Loss: 0.29206
# Validation epoch  26 (100%), Accucary: 0.84431, Mean Loss: 0.45207
#
# Train epoch  27 ( 33%), Mean Accuracy: 0.88304, Mean Loss: 0.26894
# Train epoch  27 ( 66%), Mean Accuracy: 0.87806, Mean Loss: 0.27846
# Train epoch  27 ( 99%), Mean Accuracy: 0.87436, Mean Loss: 0.28531
# Validation epoch  27 (100%), Accucary: 0.84579, Mean Loss: 0.44409
#
# Train epoch  28 ( 33%), Mean Accuracy: 0.88492, Mean Loss: 0.26416
# Train epoch  28 ( 66%), Mean Accuracy: 0.87938, Mean Loss: 0.27379
# Train epoch  28 ( 99%), Mean Accuracy: 0.87618, Mean Loss: 0.28084
# Validation epoch  28 (100%), Accucary: 0.83789, Mean Loss: 0.48197
#
# Train epoch  29 ( 33%), Mean Accuracy: 0.88643, Mean Loss: 0.25959
# Train epoch  29 ( 66%), Mean Accuracy: 0.88206, Mean Loss: 0.26830
# Train epoch  29 ( 99%), Mean Accuracy: 0.87905, Mean Loss: 0.27487
# Validation epoch  29 (100%), Accucary: 0.84523, Mean Loss: 0.45446
#
# Train epoch  30 ( 33%), Mean Accuracy: 0.89078, Mean Loss: 0.25169
# Train epoch  30 ( 66%), Mean Accuracy: 0.88634, Mean Loss: 0.26149
# Train epoch  30 ( 99%), Mean Accuracy: 0.88216, Mean Loss: 0.26934
# Validation epoch  30 (100%), Accucary: 0.82835, Mean Loss: 0.49664
#
# Train epoch  31 ( 33%), Mean Accuracy: 0.89201, Mean Loss: 0.24801
# Train epoch  31 ( 66%), Mean Accuracy: 0.88741, Mean Loss: 0.25799
# Train epoch  31 ( 99%), Mean Accuracy: 0.88437, Mean Loss: 0.26531
# Validation epoch  31 (100%), Accucary: 0.84223, Mean Loss: 0.47545
#
# Train epoch  32 ( 33%), Mean Accuracy: 0.89515, Mean Loss: 0.24279
# Train epoch  32 ( 66%), Mean Accuracy: 0.89108, Mean Loss: 0.25185
# Train epoch  32 ( 99%), Mean Accuracy: 0.88720, Mean Loss: 0.25887
# Validation epoch  32 (100%), Accucary: 0.84362, Mean Loss: 0.47901
#
# Train epoch  33 ( 33%), Mean Accuracy: 0.89749, Mean Loss: 0.23762
# Train epoch  33 ( 66%), Mean Accuracy: 0.89326, Mean Loss: 0.24602
# Train epoch  33 ( 99%), Mean Accuracy: 0.88896, Mean Loss: 0.25472
# Validation epoch  33 (100%), Accucary: 0.83892, Mean Loss: 0.49435
#
# Train epoch  34 ( 33%), Mean Accuracy: 0.89916, Mean Loss: 0.23346
# Train epoch  34 ( 66%), Mean Accuracy: 0.89446, Mean Loss: 0.24277
# Train epoch  34 ( 99%), Mean Accuracy: 0.89099, Mean Loss: 0.25023
# Validation epoch  34 (100%), Accucary: 0.85006, Mean Loss: 0.46069
#
# Train epoch  35 ( 33%), Mean Accuracy: 0.90109, Mean Loss: 0.23119
# Train epoch  35 ( 66%), Mean Accuracy: 0.89628, Mean Loss: 0.24069
# Train epoch  35 ( 99%), Mean Accuracy: 0.89350, Mean Loss: 0.24714
# Validation epoch  35 (100%), Accucary: 0.84257, Mean Loss: 0.49558
#
# Train epoch  36 ( 33%), Mean Accuracy: 0.90449, Mean Loss: 0.22371
# Train epoch  36 ( 66%), Mean Accuracy: 0.89960, Mean Loss: 0.23419
# Train epoch  36 ( 99%), Mean Accuracy: 0.89533, Mean Loss: 0.24244
# Validation epoch  36 (100%), Accucary: 0.84021, Mean Loss: 0.49036
#
# Train epoch  37 ( 33%), Mean Accuracy: 0.90698, Mean Loss: 0.21974
# Train epoch  37 ( 66%), Mean Accuracy: 0.90103, Mean Loss: 0.23186
# Train epoch  37 ( 99%), Mean Accuracy: 0.89810, Mean Loss: 0.23773
# Validation epoch  37 (100%), Accucary: 0.83809, Mean Loss: 0.51800
#
# Train epoch  38 ( 33%), Mean Accuracy: 0.90739, Mean Loss: 0.21816
# Train epoch  38 ( 66%), Mean Accuracy: 0.90226, Mean Loss: 0.22746
# Train epoch  38 ( 99%), Mean Accuracy: 0.89875, Mean Loss: 0.23521
# Validation epoch  38 (100%), Accucary: 0.84511, Mean Loss: 0.48766
#
# Train epoch  39 ( 33%), Mean Accuracy: 0.90923, Mean Loss: 0.21225
# Train epoch  39 ( 66%), Mean Accuracy: 0.90483, Mean Loss: 0.22279
# Train epoch  39 ( 99%), Mean Accuracy: 0.90105, Mean Loss: 0.23088
# Validation epoch  39 (100%), Accucary: 0.83211, Mean Loss: 0.53522
#
# Train epoch  40 ( 33%), Mean Accuracy: 0.91053, Mean Loss: 0.21100
# Train epoch  40 ( 66%), Mean Accuracy: 0.90620, Mean Loss: 0.21927
# Train epoch  40 ( 99%), Mean Accuracy: 0.90241, Mean Loss: 0.22738
# Validation epoch  40 (100%), Accucary: 0.83299, Mean Loss: 0.53268
#
# Train epoch  41 ( 33%), Mean Accuracy: 0.91264, Mean Loss: 0.20739
# Train epoch  41 ( 66%), Mean Accuracy: 0.90740, Mean Loss: 0.21741
# Train epoch  41 ( 99%), Mean Accuracy: 0.90412, Mean Loss: 0.22447
# Validation epoch  41 (100%), Accucary: 0.83355, Mean Loss: 0.52753
#
# Train epoch  42 ( 33%), Mean Accuracy: 0.91326, Mean Loss: 0.20580
# Train epoch  42 ( 66%), Mean Accuracy: 0.90856, Mean Loss: 0.21428
# Validation epoch  42 (100%), Accucary: 0.83984, Mean Loss: 0.51441
#
# Train epoch  43 ( 33%), Mean Accuracy: 0.91560, Mean Loss: 0.19814
# Train epoch  43 ( 66%), Mean Accuracy: 0.90967, Mean Loss: 0.21031
# Train epoch  43 ( 99%), Mean Accuracy: 0.90611, Mean Loss: 0.21886
# Validation epoch  43 (100%), Accucary: 0.83806, Mean Loss: 0.51972
#
# Train epoch  44 ( 33%), Mean Accuracy: 0.91668, Mean Loss: 0.19627
# Train epoch  44 ( 66%), Mean Accuracy: 0.91204, Mean Loss: 0.20722
# Train epoch  44 ( 99%), Mean Accuracy: 0.90807, Mean Loss: 0.21601
# Validation epoch  44 (100%), Accucary: 0.84182, Mean Loss: 0.51405
# best validatation accu epoch:  34, acc: 0.85006, mean loss: 0.46069
# best validatation loss epoch:  17, acc: 0.83426, mean loss: 0.43049
