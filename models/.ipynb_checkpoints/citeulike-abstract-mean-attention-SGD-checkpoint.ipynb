# %% [markdown]
# # Collaborative Filtering
# With your best friends; Cookie Optimizers :D

# %% [markdown]
# ## CiteULike

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm==2.0.0 in c:\users\micha\appdata\local\conda\conda\envs\deeplearning-02456\lib\site-packages (2.0.0)
#
#     Linking successful
#     C:\Users\Micha\AppData\Local\conda\conda\envs\deeplearning-02456\lib\site-packages\en_core_web_sm
#     -->
#     C:\Users\Micha\AppData\Local\conda\conda\envs\deeplearning-02456\lib\site-packages\spacy\data\en
#
#     You can now load the model via spacy.load('en')

# %%
from torchtext.data import Dataset, BucketIterator, Field, TabularDataset, Iterator
from torchtext.vocab import Vocab
import pandas as pd
import numpy as np
import spacy

import torch
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch import nn
import torch.nn.utils.rnn as rnn_utils

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def condence(nparr):
    uniq = np.unique(nparr)
    name2idx = {o:i for i,o in enumerate(uniq)}
    return np.array([name2idx[o] for o in nparr]), uniq

## Read set
text_information_index = 4
max_len = 1000
data='../datasets/citeulike/raw-data.csv'
#interactions = '../datasets/citeulike/user-info-small.csv'
interactions = '../datasets/citeulike/user-info.csv'
rawtext = pd.read_csv(data)
interactions = pd.read_csv(interactions)
interactions["user.id"], uniq = condence(interactions["user.id"].values)
sizes = [0.7, 0.2]

interactions = interactions.sample(frac=1) # Shuffle
filt = interactions["doc.id"].map(lambda x: len(rawtext.iloc[x,text_information_index])) <= max_len
interactions = interactions[filt]
interactions["doc.id"] = interactions["doc.id"].transform(lambda idx: rawtext.iloc[int(idx),text_information_index])

n = len(interactions)
train_size = int(sizes[0] * n)
val_size = int(sizes[1] * n)
test_size = n - train_size - val_size

train = interactions[:train_size]
val = interactions[train_size:train_size+val_size]
test = interactions[train_size+val_size:]

n = len(train)

uniq_items = np.unique(rawtext["doc.id"])[:-1]
uniq_users = np.unique(train["user.id"])[:-1]
items = set((x[0],x[1]) for x in train[["user.id","doc.id"]].values)

pairs = []
i = 0
while(i < n):
    
    item = np.random.choice(uniq_items, size = 1)[0]
    text = rawtext.iloc[int(item),text_information_index]
    user = np.random.choice(uniq_users, size = 1)[0]
    if len(text.split(' ')) <= max_len and (user,item) not in items:
        i += 1
        pairs += [(user,text,0)]
        items.add((user,item))

interactionsNegatives = np.vstack((train, pairs))

train = pd.DataFrame(data = interactionsNegatives, columns = ["user.id","doc.id", "rating"])

val.to_csv('../datasets/citeulike/val.csv', header = False, index = False)
test.to_csv('../datasets/citeulike/test.csv', header = False, index = False)

del interactionsNegatives, items, uniq_items, uniq_users, pairs, interactions, val, test

train = train.sample(frac=1) #shuffle panda style

train.to_csv('../datasets/citeulike/train.csv', header = False, index = False)

max_length = max(train["doc.id"].map(lambda x: len(x.split(' '))))
print(max_length)

del train
# Out:
# 997

# %%
spacy_en = spacy.load('en')

def tokenizer(text): # create a tokenizer function
    return [tok.text for tok in spacy_en.tokenizer(text)]

TEXT = Field(sequential=True, lower=True, include_lengths=True, fix_length=max_length)
LABEL = Field(sequential=False, use_vocab=False)
ID = Field(sequential=False, use_vocab=False)

train, val, test = TabularDataset.splits(
        path='../datasets/citeulike', train='train.csv',
        validation='val.csv', test='test.csv', format='csv',
        fields=[('ID', ID), ('Text', TEXT), ('Label', LABEL)])

TEXT.build_vocab(train, vectors="glove.6B.100d")
LABEL.build_vocab(train)
ID.build_vocab(train)

# %%
print('Text fields:')
#print('keys of TEXT.vocab:', list(TEXT.vocab.__dict__.keys()))
print(' size of vocabulary:', len(TEXT.vocab))
print(" vocabulary's embedding dimension:", TEXT.vocab.vectors.size())
print(' no. times the "the" appear in the dataset:', TEXT.vocab.freqs['the'])
# Out:
# Text fields:
#  size of vocabulary: 144191
#  vocabulary's embedding dimension: torch.Size([144191, 100])
#  no. times the "the" appear in the dataset: 954925

# %%
batch_size = (101, 102, 103)

train_iter, val_iter, test_iter = BucketIterator.splits(
    (train, val, test), batch_sizes=batch_size, sort_key=lambda x: len(x.Text), sort_within_batch = True, repeat = False)

# %%
# size of embeddings
TEXT_Shape = TEXT.vocab.vectors.size()
embedding_dim = TEXT_Shape[1]
num_items = TEXT_Shape[0]
num_users = len(ID.vocab.itos)
n_hidden = 104
l1_hidden = 105

# %%
class CFNN(nn.Module):
    def __init__(self, num_users, num_items, embedding_dim=embedding_dim, n_hidden=n_hidden, l1_hidden=l1_hidden):
        super(CFNN, self).__init__()
        self.user_emb = nn.Embedding(num_users, embedding_dim)
        self.item_emb = nn.Embedding(num_items, embedding_dim)
        self.lin1 = nn.Linear(n_hidden+embedding_dim, l1_hidden)
        self.lin2 = nn.Linear(l1_hidden, 1)
        self.drop0 = nn.Dropout(0.3)
        self.drop1 = nn.Dropout(0.3)
                
        # RNN decoding
        self.rnn = nn.LSTM(embedding_dim, n_hidden, bidirectional = True)
        self.rnnlin = nn.Linear(n_hidden*3, n_hidden)
        
        self.sigmoid = nn.Sigmoid()
        
        ## Attention module
        self.attn = nn.Linear(n_hidden*2, n_hidden)
        
    def forward(self, u, v, hidden, seq_lengths):
        #print(v.shape)
        U = self.user_emb(u)
        V = self.item_emb(v)
                
        ## Packing, Encoding, Padding
        packed = rnn_utils.pack_padded_sequence(V, seq_lengths).to(device)
        rnnOut, (hn, cn) = self.rnn(packed, hidden)
        padded, seq_lengths = rnn_utils.pad_packed_sequence(rnnOut, padding_value=0, total_length=max_length)
        seq_lengths = seq_lengths.to(device).float()
        
        # Divide each batch_element by sequence_element and sum. (mean by seq_length)
        padded = (padded.transpose(1,2) / seq_lengths).transpose(1,2)
        mean = padded.sum(dim=0)
        
        V_rnn = torch.cat([mean, hn[-1]], dim=1)
        V_rnn = F.relu(self.rnnlin(V_rnn))
                 
        x = torch.cat([U, V_rnn], dim=1)

        ## Classification
        x = self.drop0(x)
        x = F.relu(self.lin1(x))
        x = self.drop1(x)
        
        x = self.lin2(x)
        x = self.sigmoid(x)
        return x
    
    def init_hidden(self, batch_size):
        init = torch.zeros(2, batch_size, n_hidden).to(device)
        return (init,init)

# %%
## Training loop
def train(model, train_loader, optimizer, criterion, epoch, print_batch_p):
    model.train()
    
    acc_list = []
    loss_list = []
    
    for batch_idx, data in enumerate(train_loader):
        users = data.ID
        (items, seq_lengths) = data.Text
        ratings = data.Label
        batch_size = len(seq_lengths)
        
        users = users.long().to(device)
        items = items.long().to(device)
        ratings = ratings.float().to(device)      
        
        hidden_size = model.init_hidden(batch_size)
        optimizer.zero_grad()
        output = model(users, items, hidden_size, seq_lengths)
        loss = criterion(output, ratings)
        loss.backward()
        optimizer.step()
        
        # Print jumping
        percent = print_batch_p
        proc = int((len(train_loader.dataset)/batch_size)*percent)
        proc = proc if proc >= 1 else 1
        
        # Calculate accuracy
        TP,FP,TN,FN = 0,0,0,0
        output_flat = [0 if o < 0.5 else 1 for o in output.data]
        for y,yhat in zip(ratings.data, output_flat):
            y = int(y)
            if yhat == 0:
                if y != yhat:
                    FN += 1
                else:
                    TN += 1
            else:
                if y != yhat:
                    FP += 1
                else:
                    TP += 1
            
        acc_list += [(TP + TN)/(TP+FP+TN+FN)]
        loss_list += [loss.item()]
        
        if (batch_idx % proc == 0 and batch_idx != 0):
            loss_mean = sum(loss_list)/len(loss_list)
            acc_mean = sum(acc_list)/len(acc_list)
            percent = 100 * (batch_idx / (len(train_loader)-1))
            print(f'Train epoch {epoch:3d} ({percent:3.0f}%), Mean Accuracy: {acc_mean:2.5f}, Mean Loss: {loss_mean:2.5f}')
            
def validate(model, val_loader, criterion, epoch):
    model.eval()
    
    val_loss = 0
    TP,FP,TN,FN = 0,0,0,0
    
    with torch.no_grad():
        for batch_idx, data in enumerate(val_loader):
            users = data.ID
            (items, seq_lengths) = data.Text
            ratings = data.Label
            batch_size = len(seq_lengths)
            
            users = users.long().to(device)
            items = items.long().to(device)
            ratings = ratings.float().to(device)
            
            hidden_size = model.init_hidden(batch_size)
            output = model(users, items, hidden_size, seq_lengths)
            loss = criterion(output.float(), ratings)
            
            output_flat = [0 if o < 0.5 else 1 for o in output.data]
            for y,yhat in zip(ratings.data, output_flat):
                y = int(y)
                if yhat == 0:
                    if y != yhat:
                        FN += 1
                    else:
                        TN += 1
                else:
                    if y != yhat:
                        FP += 1
                    else:
                        TP += 1
            val_loss += loss.item() # sum up batch loss

    acc = (TP + TN)/(TP + TN + FP + FN)
    val_loss /= len(val_loader)
    print(f'Validation epoch {epoch:>3d} (100%), Accucary: {acc:>2.5f}, Mean Loss: {val_loss:>2.5f} \n')
    return acc, val_loss

def trainLoop(epochs, lr=0.001, wd = 1e-6, print_batch_p = 1, early_patience=5):
    # Define model    
    model = CFNN(num_users, num_items).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay = wd)
    
    accs = []
    losses = []
    best_acc = (-1,-1e16,1e16)
    best_loss = (-1,-1e16,1e16)
    early = 0
    
    for epoch in range(1, epochs + 1):
        train(model, train_iter, optimizer, criterion, epoch, print_batch_p)
        val_acc, val_loss = validate(model, val_iter, criterion, epoch)
        accs += [val_acc]
        losses += [val_loss]
        
        early += 1
        if val_acc > best_acc[-2]:
            early = 0
            best_acc = (epoch, val_acc, val_loss)
        if val_loss < best_loss[-1]:
            early = 0
            best_loss = (epoch, val_acc, val_loss)
        if early >= early_patience:
            break
        
    plt.plot(range(1,epoch+1),accs)
    plt.show()
    print(f'best validatation accu epoch: {best_acc[0]:>3.0f}, acc: {best_acc[1]:>2.5f}, mean loss: {best_acc[2]:>2.5f} \n')
    plt.plot(range(1,epoch+1),losses)
    plt.show()
    print(f'best validatation loss epoch: {best_loss[0]:>3.0f}, acc: {best_loss[1]:>2.5f}, mean loss: {best_loss[2]:>2.5f}')

# %%
trainLoop(epochs=1000, lr=0.1, wd=1e-6, print_batch_p=0.33, early_patience=10)
# Out:
# Train epoch   1 ( 33%), Mean Accuracy: 0.49016, Mean Loss: 0.70653
# Train epoch   1 ( 66%), Mean Accuracy: 0.49907, Mean Loss: 0.70406
# Train epoch   1 ( 99%), Mean Accuracy: 0.50134, Mean Loss: 0.70239
# Validation epoch   1 (100%), Accucary: 0.06532, Mean Loss: 0.78772
#
# Train epoch   2 ( 33%), Mean Accuracy: 0.50415, Mean Loss: 0.69905
# Train epoch   2 ( 66%), Mean Accuracy: 0.51083, Mean Loss: 0.69736
# Train epoch   2 ( 99%), Mean Accuracy: 0.51385, Mean Loss: 0.69645
# Validation epoch   2 (100%), Accucary: 0.84868, Mean Loss: 0.60825
#
# Train epoch   3 ( 33%), Mean Accuracy: 0.53217, Mean Loss: 0.69056
# Train epoch   3 ( 66%), Mean Accuracy: 0.54296, Mean Loss: 0.68817
# Train epoch   3 ( 99%), Mean Accuracy: 0.54642, Mean Loss: 0.68702
# Validation epoch   3 (100%), Accucary: 0.67082, Mean Loss: 0.64400
#
# Train epoch   4 ( 33%), Mean Accuracy: 0.56651, Mean Loss: 0.67923
# Train epoch   4 ( 66%), Mean Accuracy: 0.57019, Mean Loss: 0.67813
# Train epoch   4 ( 99%), Mean Accuracy: 0.57154, Mean Loss: 0.67723
# Validation epoch   4 (100%), Accucary: 0.59664, Mean Loss: 0.66646
#
# Train epoch   5 ( 33%), Mean Accuracy: 0.58335, Mean Loss: 0.67156
# Train epoch   5 ( 66%), Mean Accuracy: 0.58424, Mean Loss: 0.66998
# Train epoch   5 ( 99%), Mean Accuracy: 0.58495, Mean Loss: 0.66888
# Validation epoch   5 (100%), Accucary: 0.51436, Mean Loss: 0.70794
#
# Train epoch   6 ( 33%), Mean Accuracy: 0.59245, Mean Loss: 0.66346
# Train epoch   6 ( 66%), Mean Accuracy: 0.59608, Mean Loss: 0.66118
# Train epoch   6 ( 99%), Mean Accuracy: 0.59685, Mean Loss: 0.66048
# Validation epoch   6 (100%), Accucary: 0.75185, Mean Loss: 0.60135
#
# Train epoch   7 ( 33%), Mean Accuracy: 0.60762, Mean Loss: 0.65306
# Train epoch   7 ( 66%), Mean Accuracy: 0.60762, Mean Loss: 0.65243
# Train epoch   7 ( 99%), Mean Accuracy: 0.60752, Mean Loss: 0.65175
# Validation epoch   7 (100%), Accucary: 0.70589, Mean Loss: 0.61867
#
# Train epoch   8 ( 33%), Mean Accuracy: 0.61287, Mean Loss: 0.64864
# Train epoch   8 ( 66%), Mean Accuracy: 0.61522, Mean Loss: 0.64671
# Train epoch   8 ( 99%), Mean Accuracy: 0.61683, Mean Loss: 0.64574
# Validation epoch   8 (100%), Accucary: 0.82477, Mean Loss: 0.54801
#
# Train epoch   9 ( 33%), Mean Accuracy: 0.62147, Mean Loss: 0.64120
# Train epoch   9 ( 66%), Mean Accuracy: 0.62081, Mean Loss: 0.64253
# Train epoch   9 ( 99%), Mean Accuracy: 0.62240, Mean Loss: 0.64098
# Validation epoch   9 (100%), Accucary: 0.71114, Mean Loss: 0.61691
#
# Train epoch  10 ( 33%), Mean Accuracy: 0.63418, Mean Loss: 0.63196
# Train epoch  10 ( 66%), Mean Accuracy: 0.63171, Mean Loss: 0.63356
# Train epoch  10 ( 99%), Mean Accuracy: 0.63336, Mean Loss: 0.63258
# Validation epoch  10 (100%), Accucary: 0.53613, Mean Loss: 0.73769
#
# Train epoch  11 ( 33%), Mean Accuracy: 0.64822, Mean Loss: 0.61950
# Train epoch  11 ( 66%), Mean Accuracy: 0.64950, Mean Loss: 0.61898
# Train epoch  11 ( 99%), Mean Accuracy: 0.64867, Mean Loss: 0.61893
# Validation epoch  11 (100%), Accucary: 0.85656, Mean Loss: 0.50866
#
# Train epoch  12 ( 33%), Mean Accuracy: 0.65462, Mean Loss: 0.60936
# Train epoch  12 ( 66%), Mean Accuracy: 0.65680, Mean Loss: 0.60830
# Train epoch  12 ( 99%), Mean Accuracy: 0.65922, Mean Loss: 0.60653
# Validation epoch  12 (100%), Accucary: 0.61831, Mean Loss: 0.67577
#
# Train epoch  13 ( 33%), Mean Accuracy: 0.67400, Mean Loss: 0.59180
# Train epoch  13 ( 66%), Mean Accuracy: 0.67279, Mean Loss: 0.59219
# Train epoch  13 ( 99%), Mean Accuracy: 0.67396, Mean Loss: 0.59089
# Validation epoch  13 (100%), Accucary: 0.46556, Mean Loss: 0.82419
#
# Train epoch  14 ( 33%), Mean Accuracy: 0.68525, Mean Loss: 0.57728
# Train epoch  14 ( 66%), Mean Accuracy: 0.68452, Mean Loss: 0.57708
# Train epoch  14 ( 99%), Mean Accuracy: 0.68602, Mean Loss: 0.57544
# Validation epoch  14 (100%), Accucary: 0.76147, Mean Loss: 0.56817
#
# Train epoch  15 ( 33%), Mean Accuracy: 0.69905, Mean Loss: 0.55901
# Train epoch  15 ( 66%), Mean Accuracy: 0.70189, Mean Loss: 0.55692
# Train epoch  15 ( 99%), Mean Accuracy: 0.70164, Mean Loss: 0.55737
# Validation epoch  15 (100%), Accucary: 0.74665, Mean Loss: 0.57631
#
# Train epoch  16 ( 33%), Mean Accuracy: 0.71275, Mean Loss: 0.54215
# Train epoch  16 ( 66%), Mean Accuracy: 0.71437, Mean Loss: 0.53923
# Train epoch  16 ( 99%), Mean Accuracy: 0.71362, Mean Loss: 0.54004
# Validation epoch  16 (100%), Accucary: 0.79063, Mean Loss: 0.53695
#
# Train epoch  17 ( 33%), Mean Accuracy: 0.72258, Mean Loss: 0.52681
# Train epoch  17 ( 66%), Mean Accuracy: 0.72383, Mean Loss: 0.52485
# Train epoch  17 ( 99%), Mean Accuracy: 0.72309, Mean Loss: 0.52677
# Validation epoch  17 (100%), Accucary: 0.84217, Mean Loss: 0.48696
#
# Train epoch  18 ( 33%), Mean Accuracy: 0.73452, Mean Loss: 0.50830
# Train epoch  18 ( 66%), Mean Accuracy: 0.73214, Mean Loss: 0.51120
# Train epoch  18 ( 99%), Mean Accuracy: 0.73380, Mean Loss: 0.51028
# Validation epoch  18 (100%), Accucary: 0.74129, Mean Loss: 0.58990
#
# Train epoch  19 ( 33%), Mean Accuracy: 0.74423, Mean Loss: 0.49463
# Train epoch  19 ( 66%), Mean Accuracy: 0.74384, Mean Loss: 0.49611
# Train epoch  19 ( 99%), Mean Accuracy: 0.74189, Mean Loss: 0.49764
# Validation epoch  19 (100%), Accucary: 0.86422, Mean Loss: 0.45095
#
# Train epoch  20 ( 33%), Mean Accuracy: 0.75051, Mean Loss: 0.48246
# Train epoch  20 ( 66%), Mean Accuracy: 0.75007, Mean Loss: 0.48358
# Train epoch  20 ( 99%), Mean Accuracy: 0.74947, Mean Loss: 0.48451
# Validation epoch  20 (100%), Accucary: 0.85218, Mean Loss: 0.48372
#
# Train epoch  21 ( 33%), Mean Accuracy: 0.75971, Mean Loss: 0.47306
# Train epoch  21 ( 66%), Mean Accuracy: 0.75751, Mean Loss: 0.47518
# Train epoch  21 ( 99%), Mean Accuracy: 0.75657, Mean Loss: 0.47568
# Validation epoch  21 (100%), Accucary: 0.86050, Mean Loss: 0.47286
#
# Train epoch  22 ( 33%), Mean Accuracy: 0.76772, Mean Loss: 0.45590
# Train epoch  22 ( 66%), Mean Accuracy: 0.76299, Mean Loss: 0.46330
# Train epoch  22 ( 99%), Mean Accuracy: 0.76187, Mean Loss: 0.46495
# Validation epoch  22 (100%), Accucary: 0.86843, Mean Loss: 0.45853
#
# Train epoch  23 ( 33%), Mean Accuracy: 0.77128, Mean Loss: 0.44913
# Train epoch  23 ( 66%), Mean Accuracy: 0.76852, Mean Loss: 0.45423
# Train epoch  23 ( 99%), Mean Accuracy: 0.76766, Mean Loss: 0.45489
# Validation epoch  23 (100%), Accucary: 0.87932, Mean Loss: 0.43919
#
# Train epoch  24 ( 33%), Mean Accuracy: 0.77769, Mean Loss: 0.43997
# Train epoch  24 ( 66%), Mean Accuracy: 0.77400, Mean Loss: 0.44482
# Train epoch  24 ( 99%), Mean Accuracy: 0.77269, Mean Loss: 0.44655
# Validation epoch  24 (100%), Accucary: 0.86137, Mean Loss: 0.46808
#
# Train epoch  25 ( 33%), Mean Accuracy: 0.78081, Mean Loss: 0.43367
# Train epoch  25 ( 66%), Mean Accuracy: 0.77719, Mean Loss: 0.43821
# Train epoch  25 ( 99%), Mean Accuracy: 0.77627, Mean Loss: 0.43933
# Validation epoch  25 (100%), Accucary: 0.93878, Mean Loss: 0.37256
#
# Train epoch  26 ( 33%), Mean Accuracy: 0.78043, Mean Loss: 0.43221
# Train epoch  26 ( 66%), Mean Accuracy: 0.77950, Mean Loss: 0.43316
# Train epoch  26 ( 99%), Mean Accuracy: 0.77900, Mean Loss: 0.43259
# Validation epoch  26 (100%), Accucary: 0.93539, Mean Loss: 0.36047
#
# Train epoch  27 ( 33%), Mean Accuracy: 0.78657, Mean Loss: 0.42249
# Train epoch  27 ( 66%), Mean Accuracy: 0.78382, Mean Loss: 0.42671
# Train epoch  27 ( 99%), Mean Accuracy: 0.78217, Mean Loss: 0.42848
# Validation epoch  27 (100%), Accucary: 0.87592, Mean Loss: 0.44738
#
# Train epoch  28 ( 33%), Mean Accuracy: 0.78995, Mean Loss: 0.41842
# Train epoch  28 ( 66%), Mean Accuracy: 0.78973, Mean Loss: 0.41776
# Train epoch  28 ( 99%), Mean Accuracy: 0.78752, Mean Loss: 0.42032
# Validation epoch  28 (100%), Accucary: 0.89151, Mean Loss: 0.42154
#
# Train epoch  29 ( 33%), Mean Accuracy: 0.79347, Mean Loss: 0.40972
# Train epoch  29 ( 66%), Mean Accuracy: 0.78836, Mean Loss: 0.41622
# Train epoch  29 ( 99%), Mean Accuracy: 0.78698, Mean Loss: 0.41881
# Validation epoch  29 (100%), Accucary: 0.90951, Mean Loss: 0.40945
#
# Train epoch  30 ( 33%), Mean Accuracy: 0.79300, Mean Loss: 0.41022
# Train epoch  30 ( 66%), Mean Accuracy: 0.79329, Mean Loss: 0.40995
# Train epoch  30 ( 99%), Mean Accuracy: 0.79048, Mean Loss: 0.41341
# Validation epoch  30 (100%), Accucary: 0.92647, Mean Loss: 0.38116
#
# Train epoch  31 ( 33%), Mean Accuracy: 0.79669, Mean Loss: 0.40167
# Train epoch  31 ( 66%), Mean Accuracy: 0.79494, Mean Loss: 0.40547
# Train epoch  31 ( 99%), Mean Accuracy: 0.79273, Mean Loss: 0.40876
# Validation epoch  31 (100%), Accucary: 0.92106, Mean Loss: 0.39703
#
# Train epoch  32 ( 33%), Mean Accuracy: 0.79477, Mean Loss: 0.40031
# Train epoch  32 ( 66%), Mean Accuracy: 0.79403, Mean Loss: 0.40396
# Train epoch  32 ( 99%), Mean Accuracy: 0.79306, Mean Loss: 0.40588
# Validation epoch  32 (100%), Accucary: 0.91892, Mean Loss: 0.39179
#
# Train epoch  33 ( 33%), Mean Accuracy: 0.80099, Mean Loss: 0.39625
# Train epoch  33 ( 66%), Mean Accuracy: 0.79681, Mean Loss: 0.40237
# Train epoch  33 ( 99%), Mean Accuracy: 0.79497, Mean Loss: 0.40316
# Validation epoch  33 (100%), Accucary: 0.94633, Mean Loss: 0.35432
#
# Train epoch  34 ( 33%), Mean Accuracy: 0.79929, Mean Loss: 0.39636
# Train epoch  34 ( 66%), Mean Accuracy: 0.79925, Mean Loss: 0.39580
# Train epoch  34 ( 99%), Mean Accuracy: 0.79658, Mean Loss: 0.40053
# Validation epoch  34 (100%), Accucary: 0.95147, Mean Loss: 0.34401
#
# Train epoch  35 ( 33%), Mean Accuracy: 0.80321, Mean Loss: 0.38516
# Train epoch  35 ( 66%), Mean Accuracy: 0.79791, Mean Loss: 0.39570
# Train epoch  35 ( 99%), Mean Accuracy: 0.79679, Mean Loss: 0.39874
# Validation epoch  35 (100%), Accucary: 0.93906, Mean Loss: 0.36335
#
# Train epoch  36 ( 33%), Mean Accuracy: 0.80373, Mean Loss: 0.38853
# Train epoch  36 ( 66%), Mean Accuracy: 0.80070, Mean Loss: 0.39317
# Train epoch  36 ( 99%), Mean Accuracy: 0.79904, Mean Loss: 0.39578
# Validation epoch  36 (100%), Accucary: 0.93692, Mean Loss: 0.34590
#
# Train epoch  37 ( 33%), Mean Accuracy: 0.80489, Mean Loss: 0.38729
# Train epoch  37 ( 66%), Mean Accuracy: 0.80229, Mean Loss: 0.39070
# Train epoch  37 ( 99%), Mean Accuracy: 0.79994, Mean Loss: 0.39346
# Validation epoch  37 (100%), Accucary: 0.95317, Mean Loss: 0.34203
#
# Train epoch  38 ( 33%), Mean Accuracy: 0.80630, Mean Loss: 0.38323
# Train epoch  38 ( 66%), Mean Accuracy: 0.80235, Mean Loss: 0.39011
# Train epoch  38 ( 99%), Mean Accuracy: 0.80105, Mean Loss: 0.39199
# Validation epoch  38 (100%), Accucary: 0.93118, Mean Loss: 0.37163
#
# Train epoch  39 ( 33%), Mean Accuracy: 0.80371, Mean Loss: 0.39124
# Train epoch  39 ( 66%), Mean Accuracy: 0.80410, Mean Loss: 0.38708
# Train epoch  39 ( 99%), Mean Accuracy: 0.80279, Mean Loss: 0.39049
# Validation epoch  39 (100%), Accucary: 0.92111, Mean Loss: 0.38051
#
# Train epoch  40 ( 33%), Mean Accuracy: 0.80536, Mean Loss: 0.38460
# Train epoch  40 ( 66%), Mean Accuracy: 0.80429, Mean Loss: 0.38597
# Train epoch  40 ( 99%), Mean Accuracy: 0.80252, Mean Loss: 0.38935
# Validation epoch  40 (100%), Accucary: 0.94907, Mean Loss: 0.33690
#
# Train epoch  41 ( 33%), Mean Accuracy: 0.80330, Mean Loss: 0.38392
# Train epoch  41 ( 66%), Mean Accuracy: 0.80394, Mean Loss: 0.38267
# Train epoch  41 ( 99%), Mean Accuracy: 0.80123, Mean Loss: 0.38865
# Validation epoch  41 (100%), Accucary: 0.94699, Mean Loss: 0.34326
#
# Train epoch  42 ( 33%), Mean Accuracy: 0.80654, Mean Loss: 0.38007
# Train epoch  42 ( 66%), Mean Accuracy: 0.80482, Mean Loss: 0.38450
# Train epoch  42 ( 99%), Mean Accuracy: 0.80364, Mean Loss: 0.38623
# Validation epoch  42 (100%), Accucary: 0.94797, Mean Loss: 0.33418
#
# Train epoch  43 ( 33%), Mean Accuracy: 0.81254, Mean Loss: 0.37523
# Train epoch  43 ( 66%), Mean Accuracy: 0.80934, Mean Loss: 0.37986
# Train epoch  43 ( 99%), Mean Accuracy: 0.80605, Mean Loss: 0.38428
# Validation epoch  43 (100%), Accucary: 0.93107, Mean Loss: 0.37228
#
# Train epoch  44 ( 33%), Mean Accuracy: 0.80798, Mean Loss: 0.37875
# Train epoch  44 ( 66%), Mean Accuracy: 0.80573, Mean Loss: 0.38167
# Train epoch  44 ( 99%), Mean Accuracy: 0.80474, Mean Loss: 0.38440
# Validation epoch  44 (100%), Accucary: 0.94403, Mean Loss: 0.35003
#
# Train epoch  45 ( 33%), Mean Accuracy: 0.80768, Mean Loss: 0.37912
# Train epoch  45 ( 66%), Mean Accuracy: 0.80515, Mean Loss: 0.38245
# Train epoch  45 ( 99%), Mean Accuracy: 0.80475, Mean Loss: 0.38386
# Validation epoch  45 (100%), Accucary: 0.94371, Mean Loss: 0.33136
#
# Train epoch  46 ( 33%), Mean Accuracy: 0.80739, Mean Loss: 0.38012
# Train epoch  46 ( 66%), Mean Accuracy: 0.80745, Mean Loss: 0.37957
# Train epoch  46 ( 99%), Mean Accuracy: 0.80619, Mean Loss: 0.38224
# Validation epoch  46 (100%), Accucary: 0.93271, Mean Loss: 0.36154
#
# Train epoch  47 ( 33%), Mean Accuracy: 0.81079, Mean Loss: 0.37897
# Train epoch  47 ( 66%), Mean Accuracy: 0.80963, Mean Loss: 0.37829
# Train epoch  47 ( 99%), Mean Accuracy: 0.80698, Mean Loss: 0.38123
# Validation epoch  47 (100%), Accucary: 0.92160, Mean Loss: 0.37678
#
# Train epoch  48 ( 33%), Mean Accuracy: 0.81025, Mean Loss: 0.37873
# Train epoch  48 ( 66%), Mean Accuracy: 0.81054, Mean Loss: 0.37758
# Train epoch  48 ( 99%), Mean Accuracy: 0.80810, Mean Loss: 0.38097
# Validation epoch  48 (100%), Accucary: 0.93019, Mean Loss: 0.36451
#
# Train epoch  49 ( 33%), Mean Accuracy: 0.81273, Mean Loss: 0.37555
# Train epoch  49 ( 66%), Mean Accuracy: 0.81034, Mean Loss: 0.37671
# Train epoch  49 ( 99%), Mean Accuracy: 0.80809, Mean Loss: 0.37920
# Validation epoch  49 (100%), Accucary: 0.95005, Mean Loss: 0.32658
#
# Train epoch  50 ( 33%), Mean Accuracy: 0.81136, Mean Loss: 0.37578
# Train epoch  50 ( 66%), Mean Accuracy: 0.81116, Mean Loss: 0.37534
# Train epoch  50 ( 99%), Mean Accuracy: 0.80932, Mean Loss: 0.37852
# Validation epoch  50 (100%), Accucary: 0.94918, Mean Loss: 0.32830
#
# Train epoch  51 ( 33%), Mean Accuracy: 0.81141, Mean Loss: 0.37270
# Train epoch  51 ( 66%), Mean Accuracy: 0.81039, Mean Loss: 0.37610
# Train epoch  51 ( 99%), Mean Accuracy: 0.80862, Mean Loss: 0.37896
# Validation epoch  51 (100%), Accucary: 0.93380, Mean Loss: 0.35479
#
# Train epoch  52 ( 33%), Mean Accuracy: 0.81330, Mean Loss: 0.37235
# Train epoch  52 ( 66%), Mean Accuracy: 0.81013, Mean Loss: 0.37762
# Train epoch  52 ( 99%), Mean Accuracy: 0.80964, Mean Loss: 0.37688
# Validation epoch  52 (100%), Accucary: 0.94852, Mean Loss: 0.33412
#
# Train epoch  53 ( 33%), Mean Accuracy: 0.81474, Mean Loss: 0.37044
# Train epoch  53 ( 66%), Mean Accuracy: 0.81190, Mean Loss: 0.37452
# Train epoch  53 ( 99%), Mean Accuracy: 0.80992, Mean Loss: 0.37696
# Validation epoch  53 (100%), Accucary: 0.92177, Mean Loss: 0.37283
#
# Train epoch  54 ( 33%), Mean Accuracy: 0.81287, Mean Loss: 0.37091
# Train epoch  54 ( 66%), Mean Accuracy: 0.81284, Mean Loss: 0.37271
# Train epoch  54 ( 99%), Mean Accuracy: 0.80986, Mean Loss: 0.37573
# Validation epoch  54 (100%), Accucary: 0.93851, Mean Loss: 0.34960
#
# Train epoch  55 ( 33%), Mean Accuracy: 0.81483, Mean Loss: 0.36988
# Train epoch  55 ( 66%), Mean Accuracy: 0.81218, Mean Loss: 0.37387
# Train epoch  55 ( 99%), Mean Accuracy: 0.81048, Mean Loss: 0.37620
# Validation epoch  55 (100%), Accucary: 0.93802, Mean Loss: 0.34884
#
# Train epoch  56 ( 33%), Mean Accuracy: 0.81285, Mean Loss: 0.36866
# Train epoch  56 ( 66%), Mean Accuracy: 0.81090, Mean Loss: 0.37357
# Train epoch  56 ( 99%), Mean Accuracy: 0.81014, Mean Loss: 0.37384
# Validation epoch  56 (100%), Accucary: 0.93036, Mean Loss: 0.35348
#
# Train epoch  57 ( 33%), Mean Accuracy: 0.81668, Mean Loss: 0.36477
# Train epoch  57 ( 66%), Mean Accuracy: 0.81186, Mean Loss: 0.37375
# Train epoch  57 ( 99%), Mean Accuracy: 0.81110, Mean Loss: 0.37403
# Validation epoch  57 (100%), Accucary: 0.93906, Mean Loss: 0.35833
#
# Train epoch  58 ( 33%), Mean Accuracy: 0.81335, Mean Loss: 0.36971
# Train epoch  58 ( 66%), Mean Accuracy: 0.81172, Mean Loss: 0.37250
# Train epoch  58 ( 99%), Mean Accuracy: 0.81050, Mean Loss: 0.37525
# Validation epoch  58 (100%), Accucary: 0.94830, Mean Loss: 0.33260
#
# Train epoch  59 ( 33%), Mean Accuracy: 0.81557, Mean Loss: 0.36914
# Train epoch  59 ( 66%), Mean Accuracy: 0.81328, Mean Loss: 0.36904
# Train epoch  59 ( 99%), Mean Accuracy: 0.81182, Mean Loss: 0.37255
# Validation epoch  59 (100%), Accucary: 0.95312, Mean Loss: 0.32705
# best validatation accu epoch:  37, acc: 0.95317, mean loss: 0.34203
# best validatation loss epoch:  49, acc: 0.95005, mean loss: 0.32658

# %%
trainLoop(epochs=1000, lr=0.01, wd=1e-6, print_batch_p=0.33, early_patience=10)
# Out:
# Train epoch   1 ( 33%), Mean Accuracy: 0.49519, Mean Loss: 0.70054
# Train epoch   1 ( 66%), Mean Accuracy: 0.49480, Mean Loss: 0.69942
# Train epoch   1 ( 99%), Mean Accuracy: 0.49623, Mean Loss: 0.69844
# Validation epoch   1 (100%), Accucary: 0.48154, Mean Loss: 0.69662
#
# Train epoch   2 ( 33%), Mean Accuracy: 0.50211, Mean Loss: 0.69555
# Train epoch   2 ( 66%), Mean Accuracy: 0.50122, Mean Loss: 0.69514
# Train epoch   2 ( 99%), Mean Accuracy: 0.50206, Mean Loss: 0.69491
# Validation epoch   2 (100%), Accucary: 0.57186, Mean Loss: 0.68712
#
# Train epoch   3 ( 33%), Mean Accuracy: 0.50734, Mean Loss: 0.69365
# Train epoch   3 ( 66%), Mean Accuracy: 0.50518, Mean Loss: 0.69405
# Train epoch   3 ( 99%), Mean Accuracy: 0.50684, Mean Loss: 0.69384
# Validation epoch   3 (100%), Accucary: 0.62312, Mean Loss: 0.68137
#
# Train epoch   4 ( 33%), Mean Accuracy: 0.51400, Mean Loss: 0.69280
# Train epoch   4 ( 66%), Mean Accuracy: 0.51453, Mean Loss: 0.69272
# Train epoch   4 ( 99%), Mean Accuracy: 0.51316, Mean Loss: 0.69302
# Validation epoch   4 (100%), Accucary: 0.59144, Mean Loss: 0.68433
#
# Train epoch   5 ( 33%), Mean Accuracy: 0.51419, Mean Loss: 0.69286
# Train epoch   5 ( 66%), Mean Accuracy: 0.51606, Mean Loss: 0.69278
# Train epoch   5 ( 99%), Mean Accuracy: 0.51475, Mean Loss: 0.69298
# Validation epoch   5 (100%), Accucary: 0.70332, Mean Loss: 0.67190
#
# Train epoch   6 ( 33%), Mean Accuracy: 0.51596, Mean Loss: 0.69239
# Train epoch   6 ( 66%), Mean Accuracy: 0.51594, Mean Loss: 0.69234
# Train epoch   6 ( 99%), Mean Accuracy: 0.51714, Mean Loss: 0.69225
# Validation epoch   6 (100%), Accucary: 0.40396, Mean Loss: 0.70409
#
# Train epoch   7 ( 33%), Mean Accuracy: 0.52279, Mean Loss: 0.69154
# Train epoch   7 ( 66%), Mean Accuracy: 0.52140, Mean Loss: 0.69180
# Train epoch   7 ( 99%), Mean Accuracy: 0.52159, Mean Loss: 0.69177
# Validation epoch   7 (100%), Accucary: 0.56666, Mean Loss: 0.68521
#
# Train epoch   8 ( 33%), Mean Accuracy: 0.52834, Mean Loss: 0.69088
# Train epoch   8 ( 66%), Mean Accuracy: 0.52709, Mean Loss: 0.69121
# Train epoch   8 ( 99%), Mean Accuracy: 0.52686, Mean Loss: 0.69124
# Validation epoch   8 (100%), Accucary: 0.59544, Mean Loss: 0.68116
#
# Train epoch   9 ( 33%), Mean Accuracy: 0.52726, Mean Loss: 0.69063
# Train epoch   9 ( 66%), Mean Accuracy: 0.52540, Mean Loss: 0.69116
# Train epoch   9 ( 99%), Mean Accuracy: 0.52577, Mean Loss: 0.69108
# Validation epoch   9 (100%), Accucary: 0.57120, Mean Loss: 0.68278
#
# Train epoch  10 ( 33%), Mean Accuracy: 0.52860, Mean Loss: 0.69061
# Train epoch  10 ( 66%), Mean Accuracy: 0.52996, Mean Loss: 0.68990
# Train epoch  10 ( 99%), Mean Accuracy: 0.52911, Mean Loss: 0.69022
# Validation epoch  10 (100%), Accucary: 0.60036, Mean Loss: 0.67752
#
# Train epoch  11 ( 33%), Mean Accuracy: 0.53097, Mean Loss: 0.68989
# Train epoch  11 ( 66%), Mean Accuracy: 0.53030, Mean Loss: 0.68983
# Train epoch  11 ( 99%), Mean Accuracy: 0.53106, Mean Loss: 0.68971
# Validation epoch  11 (100%), Accucary: 0.53340, Mean Loss: 0.68825
#
# Train epoch  12 ( 33%), Mean Accuracy: 0.53187, Mean Loss: 0.68923
# Train epoch  12 ( 66%), Mean Accuracy: 0.53217, Mean Loss: 0.68928
# Train epoch  12 ( 99%), Mean Accuracy: 0.53156, Mean Loss: 0.68946
# Validation epoch  12 (100%), Accucary: 0.55282, Mean Loss: 0.68481
#
# Train epoch  13 ( 33%), Mean Accuracy: 0.53976, Mean Loss: 0.68798
# Train epoch  13 ( 66%), Mean Accuracy: 0.53734, Mean Loss: 0.68841
# Train epoch  13 ( 99%), Mean Accuracy: 0.53607, Mean Loss: 0.68861
# Validation epoch  13 (100%), Accucary: 0.61645, Mean Loss: 0.67276
#
# Train epoch  14 ( 33%), Mean Accuracy: 0.53780, Mean Loss: 0.68818
# Train epoch  14 ( 66%), Mean Accuracy: 0.53795, Mean Loss: 0.68866
# Train epoch  14 ( 99%), Mean Accuracy: 0.53843, Mean Loss: 0.68847
# Validation epoch  14 (100%), Accucary: 0.59380, Mean Loss: 0.67645
#
# Train epoch  15 ( 33%), Mean Accuracy: 0.54158, Mean Loss: 0.68719
# Train epoch  15 ( 66%), Mean Accuracy: 0.54226, Mean Loss: 0.68720
# Train epoch  15 ( 99%), Mean Accuracy: 0.54188, Mean Loss: 0.68743
# Validation epoch  15 (100%), Accucary: 0.62684, Mean Loss: 0.66952
#
# Train epoch  16 ( 33%), Mean Accuracy: 0.54415, Mean Loss: 0.68671
# Train epoch  16 ( 66%), Mean Accuracy: 0.54523, Mean Loss: 0.68654
# Train epoch  16 ( 99%), Mean Accuracy: 0.54467, Mean Loss: 0.68627
# Validation epoch  16 (100%), Accucary: 0.54445, Mean Loss: 0.68503
#
# Train epoch  17 ( 33%), Mean Accuracy: 0.54607, Mean Loss: 0.68534
# Train epoch  17 ( 66%), Mean Accuracy: 0.54738, Mean Loss: 0.68550
# Train epoch  17 ( 99%), Mean Accuracy: 0.54787, Mean Loss: 0.68539
# Validation epoch  17 (100%), Accucary: 0.58214, Mean Loss: 0.67683
#
# Train epoch  18 ( 33%), Mean Accuracy: 0.54937, Mean Loss: 0.68526
# Train epoch  18 ( 66%), Mean Accuracy: 0.55095, Mean Loss: 0.68475
# Train epoch  18 ( 99%), Mean Accuracy: 0.55029, Mean Loss: 0.68485
# Validation epoch  18 (100%), Accucary: 0.57815, Mean Loss: 0.67716
#
# Train epoch  19 ( 33%), Mean Accuracy: 0.55360, Mean Loss: 0.68381
# Train epoch  19 ( 66%), Mean Accuracy: 0.55319, Mean Loss: 0.68387
# Train epoch  19 ( 99%), Mean Accuracy: 0.55433, Mean Loss: 0.68360
# Validation epoch  19 (100%), Accucary: 0.62120, Mean Loss: 0.66555
#
# Train epoch  20 ( 33%), Mean Accuracy: 0.55961, Mean Loss: 0.68301
# Train epoch  20 ( 66%), Mean Accuracy: 0.55709, Mean Loss: 0.68312
# Train epoch  20 ( 99%), Mean Accuracy: 0.55732, Mean Loss: 0.68312
# Validation epoch  20 (100%), Accucary: 0.66612, Mean Loss: 0.65315
#
# Train epoch  21 ( 33%), Mean Accuracy: 0.56006, Mean Loss: 0.68228
# Train epoch  21 ( 66%), Mean Accuracy: 0.55836, Mean Loss: 0.68196
# Train epoch  21 ( 99%), Mean Accuracy: 0.55965, Mean Loss: 0.68172
# Validation epoch  21 (100%), Accucary: 0.64867, Mean Loss: 0.65554
#
# Train epoch  22 ( 33%), Mean Accuracy: 0.56615, Mean Loss: 0.67922
# Train epoch  22 ( 66%), Mean Accuracy: 0.56548, Mean Loss: 0.67949
# Train epoch  22 ( 99%), Mean Accuracy: 0.56351, Mean Loss: 0.68017
# Validation epoch  22 (100%), Accucary: 0.61338, Mean Loss: 0.66324
#
# Train epoch  23 ( 33%), Mean Accuracy: 0.56719, Mean Loss: 0.67792
# Train epoch  23 ( 66%), Mean Accuracy: 0.56694, Mean Loss: 0.67861
# Train epoch  23 ( 99%), Mean Accuracy: 0.56683, Mean Loss: 0.67859
# Validation epoch  23 (100%), Accucary: 0.59008, Mean Loss: 0.66745
#
# Train epoch  24 ( 33%), Mean Accuracy: 0.57019, Mean Loss: 0.67739
# Train epoch  24 ( 66%), Mean Accuracy: 0.57098, Mean Loss: 0.67687
# Train epoch  24 ( 99%), Mean Accuracy: 0.56965, Mean Loss: 0.67732
# Validation epoch  24 (100%), Accucary: 0.64172, Mean Loss: 0.64983
#
# Train epoch  25 ( 33%), Mean Accuracy: 0.57258, Mean Loss: 0.67661
# Train epoch  25 ( 66%), Mean Accuracy: 0.57251, Mean Loss: 0.67628
# Train epoch  25 ( 99%), Mean Accuracy: 0.57340, Mean Loss: 0.67598
# Validation epoch  25 (100%), Accucary: 0.60572, Mean Loss: 0.66029
#
# Train epoch  26 ( 33%), Mean Accuracy: 0.57140, Mean Loss: 0.67576
# Train epoch  26 ( 66%), Mean Accuracy: 0.57130, Mean Loss: 0.67535
# Train epoch  26 ( 99%), Mean Accuracy: 0.57189, Mean Loss: 0.67510
# Validation epoch  26 (100%), Accucary: 0.63083, Mean Loss: 0.65123
#
# Train epoch  27 ( 33%), Mean Accuracy: 0.58189, Mean Loss: 0.67141
# Train epoch  27 ( 66%), Mean Accuracy: 0.57791, Mean Loss: 0.67222
# Train epoch  27 ( 99%), Mean Accuracy: 0.57647, Mean Loss: 0.67303
# Validation epoch  27 (100%), Accucary: 0.56765, Mean Loss: 0.67121
#
# Train epoch  28 ( 33%), Mean Accuracy: 0.58021, Mean Loss: 0.67207
# Train epoch  28 ( 66%), Mean Accuracy: 0.58078, Mean Loss: 0.67185
# Train epoch  28 ( 99%), Mean Accuracy: 0.58180, Mean Loss: 0.67134
# Validation epoch  28 (100%), Accucary: 0.64002, Mean Loss: 0.64427
#
# Train epoch  29 ( 33%), Mean Accuracy: 0.58125, Mean Loss: 0.67014
# Train epoch  29 ( 66%), Mean Accuracy: 0.58140, Mean Loss: 0.67012
# Train epoch  29 ( 99%), Mean Accuracy: 0.58198, Mean Loss: 0.67015
# Validation epoch  29 (100%), Accucary: 0.66913, Mean Loss: 0.63265
#
# Train epoch  30 ( 33%), Mean Accuracy: 0.58288, Mean Loss: 0.66868
# Train epoch  30 ( 66%), Mean Accuracy: 0.58314, Mean Loss: 0.66897
# Train epoch  30 ( 99%), Mean Accuracy: 0.58390, Mean Loss: 0.66879
# Validation epoch  30 (100%), Accucary: 0.62410, Mean Loss: 0.65034
#
# Train epoch  31 ( 33%), Mean Accuracy: 0.58638, Mean Loss: 0.66712
# Train epoch  31 ( 66%), Mean Accuracy: 0.58583, Mean Loss: 0.66791
# Train epoch  31 ( 99%), Mean Accuracy: 0.58577, Mean Loss: 0.66764
# Validation epoch  31 (100%), Accucary: 0.66946, Mean Loss: 0.63178
#
# Train epoch  32 ( 33%), Mean Accuracy: 0.58697, Mean Loss: 0.66676
# Train epoch  32 ( 66%), Mean Accuracy: 0.58548, Mean Loss: 0.66727
# Train epoch  32 ( 99%), Mean Accuracy: 0.58839, Mean Loss: 0.66562
# Validation epoch  32 (100%), Accucary: 0.59511, Mean Loss: 0.66204
#
# Train epoch  33 ( 33%), Mean Accuracy: 0.58706, Mean Loss: 0.66529
# Train epoch  33 ( 66%), Mean Accuracy: 0.58751, Mean Loss: 0.66520
# Train epoch  33 ( 99%), Mean Accuracy: 0.58833, Mean Loss: 0.66492
# Validation epoch  33 (100%), Accucary: 0.66503, Mean Loss: 0.63378
#
# Train epoch  34 ( 33%), Mean Accuracy: 0.59040, Mean Loss: 0.66470
# Train epoch  34 ( 66%), Mean Accuracy: 0.59303, Mean Loss: 0.66340
# Train epoch  34 ( 99%), Mean Accuracy: 0.59209, Mean Loss: 0.66306
# Validation epoch  34 (100%), Accucary: 0.66962, Mean Loss: 0.63027
#
# Train epoch  35 ( 33%), Mean Accuracy: 0.59560, Mean Loss: 0.66064
# Train epoch  35 ( 66%), Mean Accuracy: 0.59605, Mean Loss: 0.66062
# Train epoch  35 ( 99%), Mean Accuracy: 0.59528, Mean Loss: 0.66126
# Validation epoch  35 (100%), Accucary: 0.67930, Mean Loss: 0.62599
#
# Train epoch  36 ( 33%), Mean Accuracy: 0.59612, Mean Loss: 0.66062
# Train epoch  36 ( 66%), Mean Accuracy: 0.59644, Mean Loss: 0.66046
# Train epoch  36 ( 99%), Mean Accuracy: 0.59624, Mean Loss: 0.66035
# Validation epoch  36 (100%), Accucary: 0.65594, Mean Loss: 0.63681
#
# Train epoch  37 ( 33%), Mean Accuracy: 0.59323, Mean Loss: 0.66077
# Train epoch  37 ( 66%), Mean Accuracy: 0.59498, Mean Loss: 0.65996
# Train epoch  37 ( 99%), Mean Accuracy: 0.59607, Mean Loss: 0.65939
# Validation epoch  37 (100%), Accucary: 0.64741, Mean Loss: 0.64025
#
# Train epoch  38 ( 33%), Mean Accuracy: 0.59734, Mean Loss: 0.65855
# Train epoch  38 ( 66%), Mean Accuracy: 0.59835, Mean Loss: 0.65816
# Train epoch  38 ( 99%), Mean Accuracy: 0.59831, Mean Loss: 0.65847
# Validation epoch  38 (100%), Accucary: 0.67553, Mean Loss: 0.62674
#
# Train epoch  39 ( 33%), Mean Accuracy: 0.60127, Mean Loss: 0.65659
# Train epoch  39 ( 66%), Mean Accuracy: 0.60389, Mean Loss: 0.65572
# Train epoch  39 ( 99%), Mean Accuracy: 0.60199, Mean Loss: 0.65682
# Validation epoch  39 (100%), Accucary: 0.66694, Mean Loss: 0.62979
#
# Train epoch  40 ( 33%), Mean Accuracy: 0.60509, Mean Loss: 0.65511
# Train epoch  40 ( 66%), Mean Accuracy: 0.60505, Mean Loss: 0.65575
# Train epoch  40 ( 99%), Mean Accuracy: 0.60445, Mean Loss: 0.65579
# Validation epoch  40 (100%), Accucary: 0.64320, Mean Loss: 0.64146
#
# Train epoch  41 ( 33%), Mean Accuracy: 0.60094, Mean Loss: 0.65764
# Train epoch  41 ( 66%), Mean Accuracy: 0.60288, Mean Loss: 0.65594
# Train epoch  41 ( 99%), Mean Accuracy: 0.60269, Mean Loss: 0.65619
# Validation epoch  41 (100%), Accucary: 0.62947, Mean Loss: 0.64786
#
# Train epoch  42 ( 33%), Mean Accuracy: 0.60247, Mean Loss: 0.65653
# Train epoch  42 ( 66%), Mean Accuracy: 0.60403, Mean Loss: 0.65506
# Train epoch  42 ( 99%), Mean Accuracy: 0.60423, Mean Loss: 0.65451
# Validation epoch  42 (100%), Accucary: 0.67816, Mean Loss: 0.62345
#
# Train epoch  43 ( 33%), Mean Accuracy: 0.60982, Mean Loss: 0.65105
# Train epoch  43 ( 66%), Mean Accuracy: 0.60752, Mean Loss: 0.65236
# Train epoch  43 ( 99%), Mean Accuracy: 0.60769, Mean Loss: 0.65260
# Validation epoch  43 (100%), Accucary: 0.64309, Mean Loss: 0.63977
#
# Train epoch  44 ( 33%), Mean Accuracy: 0.61124, Mean Loss: 0.65113
# Train epoch  44 ( 66%), Mean Accuracy: 0.60925, Mean Loss: 0.65161
# Train epoch  44 ( 99%), Mean Accuracy: 0.60988, Mean Loss: 0.65118
# Validation epoch  44 (100%), Accucary: 0.66825, Mean Loss: 0.62625
#
# Train epoch  45 ( 33%), Mean Accuracy: 0.60573, Mean Loss: 0.65218
# Train epoch  45 ( 66%), Mean Accuracy: 0.60844, Mean Loss: 0.65037
# Train epoch  45 ( 99%), Mean Accuracy: 0.61005, Mean Loss: 0.65022
# Validation epoch  45 (100%), Accucary: 0.69801, Mean Loss: 0.61091
#
# Train epoch  46 ( 33%), Mean Accuracy: 0.61081, Mean Loss: 0.65084
# Train epoch  46 ( 66%), Mean Accuracy: 0.61049, Mean Loss: 0.65071
# Train epoch  46 ( 99%), Mean Accuracy: 0.61299, Mean Loss: 0.64954
# Validation epoch  46 (100%), Accucary: 0.66158, Mean Loss: 0.62928
#
# Train epoch  47 ( 33%), Mean Accuracy: 0.61686, Mean Loss: 0.64729
# Train epoch  47 ( 66%), Mean Accuracy: 0.61467, Mean Loss: 0.64852
# Train epoch  47 ( 99%), Mean Accuracy: 0.61427, Mean Loss: 0.64797
# Validation epoch  47 (100%), Accucary: 0.69101, Mean Loss: 0.61385
#
# Train epoch  48 ( 33%), Mean Accuracy: 0.61611, Mean Loss: 0.64861
# Train epoch  48 ( 66%), Mean Accuracy: 0.61790, Mean Loss: 0.64669
# Train epoch  48 ( 99%), Mean Accuracy: 0.61675, Mean Loss: 0.64692
# Validation epoch  48 (100%), Accucary: 0.68986, Mean Loss: 0.61500
#
# Train epoch  49 ( 33%), Mean Accuracy: 0.61615, Mean Loss: 0.64576
# Train epoch  49 ( 66%), Mean Accuracy: 0.61596, Mean Loss: 0.64626
# Train epoch  49 ( 99%), Mean Accuracy: 0.61717, Mean Loss: 0.64539
# Validation epoch  49 (100%), Accucary: 0.66661, Mean Loss: 0.62482
#
# Train epoch  50 ( 33%), Mean Accuracy: 0.61982, Mean Loss: 0.64433
# Train epoch  50 ( 66%), Mean Accuracy: 0.62039, Mean Loss: 0.64374
# Validation epoch  50 (100%), Accucary: 0.63756, Mean Loss: 0.63946
#
# Train epoch  51 ( 33%), Mean Accuracy: 0.62383, Mean Loss: 0.64339
# Train epoch  51 ( 66%), Mean Accuracy: 0.62304, Mean Loss: 0.64256
# Train epoch  51 ( 99%), Mean Accuracy: 0.62282, Mean Loss: 0.64264
# Validation epoch  51 (100%), Accucary: 0.66875, Mean Loss: 0.62114
#
# Train epoch  52 ( 33%), Mean Accuracy: 0.62305, Mean Loss: 0.64122
# Train epoch  52 ( 66%), Mean Accuracy: 0.62522, Mean Loss: 0.63987
# Train epoch  52 ( 99%), Mean Accuracy: 0.62414, Mean Loss: 0.64077
# Validation epoch  52 (100%), Accucary: 0.64079, Mean Loss: 0.63771
#
# Train epoch  53 ( 33%), Mean Accuracy: 0.62915, Mean Loss: 0.63738
# Train epoch  53 ( 66%), Mean Accuracy: 0.63071, Mean Loss: 0.63560
# Train epoch  53 ( 99%), Mean Accuracy: 0.62775, Mean Loss: 0.63774
# Validation epoch  53 (100%), Accucary: 0.66262, Mean Loss: 0.62466
#
# Train epoch  54 ( 33%), Mean Accuracy: 0.62981, Mean Loss: 0.63630
# Train epoch  54 ( 66%), Mean Accuracy: 0.63066, Mean Loss: 0.63594
# Train epoch  54 ( 99%), Mean Accuracy: 0.63051, Mean Loss: 0.63586
# Validation epoch  54 (100%), Accucary: 0.75584, Mean Loss: 0.56466
#
# Train epoch  55 ( 33%), Mean Accuracy: 0.63149, Mean Loss: 0.63560
# Train epoch  55 ( 66%), Mean Accuracy: 0.63124, Mean Loss: 0.63527
# Train epoch  55 ( 99%), Mean Accuracy: 0.63215, Mean Loss: 0.63460
# Validation epoch  55 (100%), Accucary: 0.67454, Mean Loss: 0.61804
#
# Train epoch  56 ( 33%), Mean Accuracy: 0.63666, Mean Loss: 0.63251
# Train epoch  56 ( 66%), Mean Accuracy: 0.63786, Mean Loss: 0.63204
# Train epoch  56 ( 99%), Mean Accuracy: 0.63652, Mean Loss: 0.63257
# Validation epoch  56 (100%), Accucary: 0.66481, Mean Loss: 0.62418
#
# Train epoch  57 ( 33%), Mean Accuracy: 0.63855, Mean Loss: 0.63002
# Train epoch  57 ( 66%), Mean Accuracy: 0.63932, Mean Loss: 0.62986
# Train epoch  57 ( 99%), Mean Accuracy: 0.63842, Mean Loss: 0.63017
# Validation epoch  57 (100%), Accucary: 0.65638, Mean Loss: 0.62703
#
# Train epoch  58 ( 33%), Mean Accuracy: 0.63988, Mean Loss: 0.62829
# Train epoch  58 ( 66%), Mean Accuracy: 0.64203, Mean Loss: 0.62715
# Train epoch  58 ( 99%), Mean Accuracy: 0.64251, Mean Loss: 0.62732
# Validation epoch  58 (100%), Accucary: 0.75956, Mean Loss: 0.56054
#
# Train epoch  59 ( 33%), Mean Accuracy: 0.64834, Mean Loss: 0.62305
# Train epoch  59 ( 66%), Mean Accuracy: 0.64652, Mean Loss: 0.62320
# Validation epoch  59 (100%), Accucary: 0.69555, Mean Loss: 0.60133
#
# Train epoch  60 ( 33%), Mean Accuracy: 0.65124, Mean Loss: 0.62042
# Train epoch  60 ( 66%), Mean Accuracy: 0.65077, Mean Loss: 0.62027
# Train epoch  60 ( 99%), Mean Accuracy: 0.64904, Mean Loss: 0.62151
# Validation epoch  60 (100%), Accucary: 0.60955, Mean Loss: 0.65857
#
# Train epoch  61 ( 33%), Mean Accuracy: 0.65507, Mean Loss: 0.61835
# Train epoch  61 ( 66%), Mean Accuracy: 0.65368, Mean Loss: 0.61840
# Train epoch  61 ( 99%), Mean Accuracy: 0.65105, Mean Loss: 0.61927
# Validation epoch  61 (100%), Accucary: 0.65644, Mean Loss: 0.62561
# Train epoch  62 ( 33%), Mean Accuracy: 0.65611, Mean Loss: 0.61533
# Train epoch  62 ( 66%), Mean Accuracy: 0.65471, Mean Loss: 0.61589
# Train epoch  62 ( 99%), Mean Accuracy: 0.65479, Mean Loss: 0.61512
# Validation epoch  62 (100%), Accucary: 0.75141, Mean Loss: 0.55736
#
# Train epoch  63 ( 33%), Mean Accuracy: 0.65422, Mean Loss: 0.61489
# Train epoch  63 ( 66%), Mean Accuracy: 0.65567, Mean Loss: 0.61388
# Train epoch  63 ( 99%), Mean Accuracy: 0.65649, Mean Loss: 0.61362
# Validation epoch  63 (100%), Accucary: 0.74649, Mean Loss: 0.56027
#
# Train epoch  64 ( 33%), Mean Accuracy: 0.66148, Mean Loss: 0.60791
# Train epoch  64 ( 66%), Mean Accuracy: 0.66065, Mean Loss: 0.60849
# Train epoch  64 ( 99%), Mean Accuracy: 0.65962, Mean Loss: 0.60951
# Validation epoch  64 (100%), Accucary: 0.77346, Mean Loss: 0.53774
#
# Train epoch  65 ( 33%), Mean Accuracy: 0.66471, Mean Loss: 0.60453
# Train epoch  65 ( 66%), Mean Accuracy: 0.66318, Mean Loss: 0.60643
# Train epoch  65 ( 99%), Mean Accuracy: 0.66294, Mean Loss: 0.60622
# Validation epoch  65 (100%), Accucary: 0.76640, Mean Loss: 0.54312
#
# Train epoch  66 ( 33%), Mean Accuracy: 0.66516, Mean Loss: 0.60390
# Train epoch  66 ( 66%), Mean Accuracy: 0.66492, Mean Loss: 0.60377
# Train epoch  66 ( 99%), Mean Accuracy: 0.66614, Mean Loss: 0.60294
# Validation epoch  66 (100%), Accucary: 0.71147, Mean Loss: 0.58651
#
# Train epoch  67 ( 33%), Mean Accuracy: 0.66946, Mean Loss: 0.60013
# Train epoch  67 ( 66%), Mean Accuracy: 0.66920, Mean Loss: 0.59952
# Train epoch  67 ( 99%), Mean Accuracy: 0.66874, Mean Loss: 0.59888
# Validation epoch  67 (100%), Accucary: 0.63417, Mean Loss: 0.64689
#
# Train epoch  68 ( 33%), Mean Accuracy: 0.67253, Mean Loss: 0.59743
# Train epoch  68 ( 66%), Mean Accuracy: 0.67166, Mean Loss: 0.59686
# Train epoch  68 ( 99%), Mean Accuracy: 0.67220, Mean Loss: 0.59626
# Validation epoch  68 (100%), Accucary: 0.68756, Mean Loss: 0.60401
#
# Train epoch  69 ( 33%), Mean Accuracy: 0.67464, Mean Loss: 0.59399
# Train epoch  69 ( 66%), Mean Accuracy: 0.67546, Mean Loss: 0.59344
# Train epoch  69 ( 99%), Mean Accuracy: 0.67563, Mean Loss: 0.59247
# Validation epoch  69 (100%), Accucary: 0.68986, Mean Loss: 0.60369
#
# Train epoch  70 ( 33%), Mean Accuracy: 0.68043, Mean Loss: 0.58711
# Train epoch  70 ( 66%), Mean Accuracy: 0.67975, Mean Loss: 0.58761
# Train epoch  70 ( 99%), Mean Accuracy: 0.67909, Mean Loss: 0.58749
# Validation epoch  70 (100%), Accucary: 0.79512, Mean Loss: 0.51327
#
# Train epoch  71 ( 33%), Mean Accuracy: 0.68187, Mean Loss: 0.58680
# Train epoch  71 ( 66%), Mean Accuracy: 0.68143, Mean Loss: 0.58535
# Train epoch  71 ( 99%), Mean Accuracy: 0.68219, Mean Loss: 0.58432
# Validation epoch  71 (100%), Accucary: 0.72805, Mean Loss: 0.57091
#
# Train epoch  72 ( 33%), Mean Accuracy: 0.69012, Mean Loss: 0.57764
# Train epoch  72 ( 66%), Mean Accuracy: 0.68905, Mean Loss: 0.57785
# Train epoch  72 ( 99%), Mean Accuracy: 0.68762, Mean Loss: 0.57922
# Validation epoch  72 (100%), Accucary: 0.70250, Mean Loss: 0.59469
#
# Train epoch  73 ( 33%), Mean Accuracy: 0.69378, Mean Loss: 0.57345
# Train epoch  73 ( 66%), Mean Accuracy: 0.69294, Mean Loss: 0.57313
# Train epoch  73 ( 99%), Mean Accuracy: 0.69219, Mean Loss: 0.57324
# Validation epoch  73 (100%), Accucary: 0.81263, Mean Loss: 0.49017
#
# Train epoch  74 ( 33%), Mean Accuracy: 0.69168, Mean Loss: 0.57240
# Train epoch  74 ( 66%), Mean Accuracy: 0.69490, Mean Loss: 0.57074
# Train epoch  74 ( 99%), Mean Accuracy: 0.69406, Mean Loss: 0.57089
# Validation epoch  74 (100%), Accucary: 0.70529, Mean Loss: 0.58835
#
# Train epoch  75 ( 33%), Mean Accuracy: 0.69907, Mean Loss: 0.56434
# Train epoch  75 ( 66%), Mean Accuracy: 0.69735, Mean Loss: 0.56596
# Train epoch  75 ( 99%), Mean Accuracy: 0.69799, Mean Loss: 0.56604
# Validation epoch  75 (100%), Accucary: 0.80907, Mean Loss: 0.48841
#
# Train epoch  76 ( 33%), Mean Accuracy: 0.70434, Mean Loss: 0.56006
# Train epoch  76 ( 66%), Mean Accuracy: 0.70238, Mean Loss: 0.56110
# Train epoch  76 ( 99%), Mean Accuracy: 0.70210, Mean Loss: 0.56216
# Validation epoch  76 (100%), Accucary: 0.77138, Mean Loss: 0.52834
#
# Train epoch  77 ( 33%), Mean Accuracy: 0.70425, Mean Loss: 0.55998
# Train epoch  77 ( 66%), Mean Accuracy: 0.70586, Mean Loss: 0.55755
# Train epoch  77 ( 99%), Mean Accuracy: 0.70424, Mean Loss: 0.55868
# Validation epoch  77 (100%), Accucary: 0.76695, Mean Loss: 0.52953
#
# Train epoch  78 ( 33%), Mean Accuracy: 0.70373, Mean Loss: 0.55579
# Train epoch  78 ( 66%), Mean Accuracy: 0.70645, Mean Loss: 0.55295
# Train epoch  78 ( 99%), Mean Accuracy: 0.70529, Mean Loss: 0.55433
# Validation epoch  78 (100%), Accucary: 0.79600, Mean Loss: 0.50263
#
# Train epoch  79 ( 33%), Mean Accuracy: 0.70952, Mean Loss: 0.54874
# Train epoch  79 ( 66%), Mean Accuracy: 0.71155, Mean Loss: 0.54824
# Train epoch  79 ( 99%), Mean Accuracy: 0.71105, Mean Loss: 0.54886
# Validation epoch  79 (100%), Accucary: 0.75513, Mean Loss: 0.53911
#
# Train epoch  80 ( 33%), Mean Accuracy: 0.71289, Mean Loss: 0.54552
# Train epoch  80 ( 66%), Mean Accuracy: 0.71334, Mean Loss: 0.54584
# Train epoch  80 ( 99%), Mean Accuracy: 0.71301, Mean Loss: 0.54549
# Validation epoch  80 (100%), Accucary: 0.83708, Mean Loss: 0.45492
#
# Train epoch  81 ( 33%), Mean Accuracy: 0.71675, Mean Loss: 0.53794
# Train epoch  81 ( 66%), Mean Accuracy: 0.71564, Mean Loss: 0.53984
# Train epoch  81 ( 99%), Mean Accuracy: 0.71545, Mean Loss: 0.54036
# Validation epoch  81 (100%), Accucary: 0.80256, Mean Loss: 0.49331
#
# Train epoch  82 ( 33%), Mean Accuracy: 0.72530, Mean Loss: 0.52972
# Train epoch  82 ( 66%), Mean Accuracy: 0.72159, Mean Loss: 0.53496
# Train epoch  82 ( 99%), Mean Accuracy: 0.72170, Mean Loss: 0.53414
# Validation epoch  82 (100%), Accucary: 0.83227, Mean Loss: 0.46075
#
# Train epoch  83 ( 33%), Mean Accuracy: 0.72187, Mean Loss: 0.53280
# Train epoch  83 ( 66%), Mean Accuracy: 0.72050, Mean Loss: 0.53302
# Train epoch  83 ( 99%), Mean Accuracy: 0.72212, Mean Loss: 0.53142
# Validation epoch  83 (100%), Accucary: 0.80267, Mean Loss: 0.49793
#
# Train epoch  84 ( 33%), Mean Accuracy: 0.72700, Mean Loss: 0.52432
# Train epoch  84 ( 66%), Mean Accuracy: 0.72633, Mean Loss: 0.52721
# Train epoch  84 ( 99%), Mean Accuracy: 0.72610, Mean Loss: 0.52753
# Validation epoch  84 (100%), Accucary: 0.85048, Mean Loss: 0.44330
#
# Train epoch  85 ( 33%), Mean Accuracy: 0.72981, Mean Loss: 0.52040
# Train epoch  85 ( 66%), Mean Accuracy: 0.72928, Mean Loss: 0.52024
# Train epoch  85 ( 99%), Mean Accuracy: 0.72976, Mean Loss: 0.52083
# Validation epoch  85 (100%), Accucary: 0.74315, Mean Loss: 0.55627
#
# Train epoch  86 ( 33%), Mean Accuracy: 0.73333, Mean Loss: 0.51537
# Train epoch  86 ( 66%), Mean Accuracy: 0.73059, Mean Loss: 0.51812
# Train epoch  86 ( 99%), Mean Accuracy: 0.73098, Mean Loss: 0.51841
# Validation epoch  86 (100%), Accucary: 0.76820, Mean Loss: 0.53010
#
# Train epoch  87 ( 33%), Mean Accuracy: 0.73149, Mean Loss: 0.51429
# Train epoch  87 ( 66%), Mean Accuracy: 0.73292, Mean Loss: 0.51441
# Train epoch  87 ( 99%), Mean Accuracy: 0.73486, Mean Loss: 0.51306
# Validation epoch  87 (100%), Accucary: 0.89906, Mean Loss: 0.37854
#
# Train epoch  88 ( 33%), Mean Accuracy: 0.73957, Mean Loss: 0.50776
# Train epoch  88 ( 66%), Mean Accuracy: 0.73854, Mean Loss: 0.50864
# Train epoch  88 ( 99%), Mean Accuracy: 0.73756, Mean Loss: 0.50826
# Validation epoch  88 (100%), Accucary: 0.88271, Mean Loss: 0.40045
#
# Train epoch  89 ( 33%), Mean Accuracy: 0.74009, Mean Loss: 0.50584
# Train epoch  89 ( 66%), Mean Accuracy: 0.73945, Mean Loss: 0.50543
# Train epoch  89 ( 99%), Mean Accuracy: 0.73952, Mean Loss: 0.50578
# Validation epoch  89 (100%), Accucary: 0.78292, Mean Loss: 0.51510
#
# Train epoch  90 ( 33%), Mean Accuracy: 0.74482, Mean Loss: 0.50091
# Train epoch  90 ( 66%), Mean Accuracy: 0.74561, Mean Loss: 0.49971
# Train epoch  90 ( 99%), Mean Accuracy: 0.74570, Mean Loss: 0.49848
# Validation epoch  90 (100%), Accucary: 0.75682, Mean Loss: 0.54431
#
# Train epoch  91 ( 33%), Mean Accuracy: 0.74442, Mean Loss: 0.49460
# Train epoch  91 ( 66%), Mean Accuracy: 0.74533, Mean Loss: 0.49427
# Train epoch  91 ( 99%), Mean Accuracy: 0.74540, Mean Loss: 0.49514
# Validation epoch  91 (100%), Accucary: 0.81077, Mean Loss: 0.47984
#
# Train epoch  92 ( 33%), Mean Accuracy: 0.74992, Mean Loss: 0.49129
# Train epoch  92 ( 66%), Mean Accuracy: 0.74970, Mean Loss: 0.49146
# Train epoch  92 ( 99%), Mean Accuracy: 0.74859, Mean Loss: 0.49272
# Validation epoch  92 (100%), Accucary: 0.85081, Mean Loss: 0.44262
#
# Train epoch  93 ( 33%), Mean Accuracy: 0.75200, Mean Loss: 0.48801
# Train epoch  93 ( 66%), Mean Accuracy: 0.74932, Mean Loss: 0.48920
# Train epoch  93 ( 99%), Mean Accuracy: 0.74900, Mean Loss: 0.48937
# Validation epoch  93 (100%), Accucary: 0.83396, Mean Loss: 0.45856
#
# Train epoch  94 ( 33%), Mean Accuracy: 0.75366, Mean Loss: 0.48394
# Train epoch  94 ( 66%), Mean Accuracy: 0.75252, Mean Loss: 0.48468
# Train epoch  94 ( 99%), Mean Accuracy: 0.75229, Mean Loss: 0.48519
# Validation epoch  94 (100%), Accucary: 0.82280, Mean Loss: 0.46899
#
# Train epoch  95 ( 33%), Mean Accuracy: 0.75403, Mean Loss: 0.48200
# Train epoch  95 ( 66%), Mean Accuracy: 0.75440, Mean Loss: 0.48083
# Train epoch  95 ( 99%), Mean Accuracy: 0.75443, Mean Loss: 0.48182
# Validation epoch  95 (100%), Accucary: 0.80344, Mean Loss: 0.49361
#
# Train epoch  96 ( 33%), Mean Accuracy: 0.75798, Mean Loss: 0.47623
# Train epoch  96 ( 66%), Mean Accuracy: 0.75838, Mean Loss: 0.47461
# Train epoch  96 ( 99%), Mean Accuracy: 0.75658, Mean Loss: 0.47721
# Validation epoch  96 (100%), Accucary: 0.80021, Mean Loss: 0.49936
#
# Train epoch  97 ( 33%), Mean Accuracy: 0.75784, Mean Loss: 0.47342
# Train epoch  97 ( 66%), Mean Accuracy: 0.75673, Mean Loss: 0.47640
# Train epoch  97 ( 99%), Mean Accuracy: 0.75933, Mean Loss: 0.47274
# Validation epoch  97 (100%), Accucary: 0.87286, Mean Loss: 0.41467
# best validatation accu epoch:  87, acc: 0.89906, mean loss: 0.37854
# best validatation loss epoch:  87, acc: 0.89906, mean loss: 0.37854

# %%
trainLoop(epochs=1000, lr=0.001, wd=1e-6, print_batch_p=0.33, early_patience=10)
# Out:
# Train epoch   1 ( 33%), Mean Accuracy: 0.50089, Mean Loss: 0.70727
# Train epoch   1 ( 66%), Mean Accuracy: 0.50283, Mean Loss: 0.70373
